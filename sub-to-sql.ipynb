# %%
require 'srt'
subtitle_filename = "Dredd.2012.German.UHDBD.2160p.HDR10.HEVC.DTSHD.DUBBED.DL.Remux-pmHD.eng.sdh.srt"
movie_filename = "Dredd.2012.1080p.BluRay.x264.YIFY.mp4"
# Out:
# "Dredd.2012.1080p.BluRay.x264.YIFY.mp4"

# %% [markdown]
# Each line exposes the following methods/members:
#     sequence The incrementing subtitle ID (starts at 1)
#     text An Array holding one or multiple lines of text.
#     start_time The subtitle start timecode in seconds as a float
#     end_time The subtitle end timecode in seconds as a float
#     time_str Returns a timecode string of the form "00:53:35,558 --> 00:53:36,556"
#     display_coordinates Optional display coordinates of the form "X1:100 X2:600 Y1:100 Y2:400"

# %%
file = SRT::File.parse(File.new(subtitle_filename))
  file.lines.each do |line|
    puts line.sequence
    puts line.text
    puts line.start_time
    puts line.end_time
    puts line.time_str
    puts line.display_coordinates
  end
# Out:
# 0
# ["DREDD:<i> America is an irradiated wasteland.</i>"]
# 59.978
# 63.065
# 00:00:59,978 --> 00:01:03,065
#
# 2
# ["<i>Within it lies a city.</i>"]
# 64.816
# 66.777
# 00:01:04,816 --> 00:01:06,777
#
# 3
# ["<i>Outside the boundary walls a desert.</i>"]
# 68.737
# 71.865
# 00:01:08,737 --> 00:01:11,865
#
# 4
# ["<i>A cursed earth.</i>"]
# 71.949
# 73.659
# 00:01:11,949 --> 00:01:13,659
#
# 5
# ["<i>Inside the walls a cursed city,</i>"]
# 75.16
# 78.664
# 00:01:15,160 --> 00:01:18,664
#
# 6
# ["<i>stretching from Boston to Washington, D.C.</i>"]
# 78.747
# 82.125
# 00:01:18,747 --> 00:01:22,125
#
# 7
# ["<i>An unbroken concrete landscape.</i>"]
# 83.252
# 85.921
# 00:01:23,252 --> 00:01:25,921
#
# 8
# ["<i>800 million people</i>"]
# 87.673
# 89.091
# 00:01:27,673 --> 00:01:29,091
#
# 9
# ["<i>living in the ruin of the old world</i>"]
# 89.174
# 92.135
# 00:01:29,174 --> 00:01:32,135
#
# 10
# ["<i>and the mega structures of the new one.</i>"]
# 92.803
# 95.472
# 00:01:32,803 --> 00:01:35,472
#
# 11
# ["<i>Mega blocks. Mega highways.</i>"]
# 97.766
# 101.103
# 00:01:37,766 --> 00:01:41,103
#
# 12
# ["<i>Mega City One.</i>"]
# 102.521
# 104.439
# 00:01:42,521 --> 00:01:44,439
#
# 13
# ["<i>Convulsing. Choking.</i>"]
# 113.198
# 116.285
# 00:01:53,198 --> 00:01:56,285
#
# 14
# ["<i>Breaking under its own weight.</i>"]
# 118.87
# 121.331
# 00:01:58,870 --> 00:02:01,331
#
# 15
# ["<i>Citizens in fear of the street.</i>"]
# 125.46
# 128.13
# 00:02:05,460 --> 00:02:08,130
#
# 16
# ["<i>The gun. The gang.</i>"]
# 128.672
# 132.342
# 00:02:08,672 --> 00:02:12,342
#
# 17
# ["<i>Only one thing fighting", "for order in the chaos,</i>"]
# 136.722
# 140.058
# 00:02:16,722 --> 00:02:20,058
#
# 18
# ["<i>the men and women of the Hall of Justice.</i>"]
# 141.31
# 144.146
# 00:02:21,310 --> 00:02:24,146
#
# 19
# ["<i>Juries.</i>"]
# 148.4
# 149.818
# 00:02:28,400 --> 00:02:29,818
#
# 20
# ["<i>Executioners.</i>"]
# 151.987
# 153.53
# 00:02:31,987 --> 00:02:33,530
#
# 21
# ["<i>Judges.</i>"]
# 156.241
# 157.367
# 00:02:36,241 --> 00:02:37,367
#
# 22
# ["MALE JUDGE:<i> Responders needed", "at a square at 1117.</i>"]
# 166.668
# 170.005
# 00:02:46,668 --> 00:02:50,005
#
# 23
# ["<i>Code 10-10.</i>"]
# 170.088
# 171.173
# 00:02:50,088 --> 00:02:51,173
#
# 24
# ["FEMALE JUDGE:<i> Leisure complex.</i>"]
# 171.256
# 172.341
# 00:02:51,256 --> 00:02:52,341
#
# 25
# ["<i>Shots fired.</i>"]
# 172.424
# 173.467
# 00:02:52,424 --> 00:02:53,467
#
# 26
# ["MALE JUDGE:<i> Out of vehicle, in pursuit.</i>"]
# 173.55
# 174.926
# 00:02:53,550 --> 00:02:54,926
#
# 27
# ["<i>Request aerial surveillance.</i>"]
# 175.01
# 176.47
# 00:02:55,010 --> 00:02:56,470
#
# 28
# ["CONTROL:<i> I have a control drone</i>"]
# 176.553
# 177.596
# 00:02:56,553 --> 00:02:57,596
#
# 29
# ["flagging three perps."]
# 177.679
# 179.765
# 00:02:57,679 --> 00:02:59,765
#
# 30
# ["Responders needed", "in Sub-Sector 20, Flyover 5."]
# 180.182
# 183.185
# 00:03:00,182 --> 00:03:03,185
#
# 31
# ["We have a positive ID on three suspects"]
# 183.268
# 185.604
# 00:03:03,268 --> 00:03:05,604
#
# 32
# ["wanted on multiple counts."]
# 185.687
# 186.855
# 00:03:05,687 --> 00:03:06,855
#
# 33
# ["Any Judges, please respond."]
# 186.938
# 188.523
# 00:03:06,938 --> 00:03:08,523
#
# 34
# ["Dredd to Control.", "In pursuit of vehicle, Sector 13."]
# 190.275
# 194.78
# 00:03:10,275 --> 00:03:14,780
#
# 35
# ["Driving erratic."]
# 196.615
# 197.699
# 00:03:16,615 --> 00:03:17,699
#
# 36
# ["Suspects are under the", "influence of narcotics."]
# 197.783
# 200.619
# 00:03:17,783 --> 00:03:20,619
#
# 37
# ["(DISTORTED VOICE) Got a Judge on our tail."]
# 223.809
# 227.979
# 00:03:43,809 --> 00:03:47,979
#
# 38
# ["What?"]
# 229.648
# 230.649
# 00:03:49,648 --> 00:03:50,649
#
# 39
# ["I said, we got a Judge on our tail!"]
# 230.816
# 232.567
# 00:03:50,816 --> 00:03:52,567
#
# 40
# ["Take him out or we're dead fucking meat!"]
# 232.651
# 234.986
# 00:03:52,651 --> 00:03:54,986
#
# 41
# ["(SIRENS WAILING)"]
# 235.153
# 236.571
# 00:03:55,153 --> 00:03:56,571
#
# 42
# ["Fuck!"]
# 237.614
# 238.657
# 00:03:57,614 --> 00:03:58,657
#
# 43
# ["Do you require backup?"]
# 240.325
# 241.66
# 00:04:00,325 --> 00:04:01,660
#
# 44
# ["No."]
# 241.952
# 242.953
# 00:04:01,952 --> 00:04:02,953
#
# 45
# ["(YELLS) Fucker!"]
# 246.164
# 247.666
# 00:04:06,164 --> 00:04:07,666
#
# 46
# ["(BULLETS RICOCHETING)"]
# 248.834
# 250.752
# 00:04:08,834 --> 00:04:10,752
#
# 47
# ["(YELLING)"]
# 251.002
# 252.129
# 00:04:11,002 --> 00:04:12,129
#
# 48
# ["I can't get him! Straighten the fuck out!"]
# 253.171
# 255.674
# 00:04:13,171 --> 00:04:15,674
#
# 49
# ["CONTROL:<i> Be advised.</i>"]
# 270.021
# 271.106
# 00:04:30,021 --> 00:04:31,106
#
# 50
# ["<i>We have lost visual.</i>"]
# 271.189
# 272.274
# 00:04:31,189 --> 00:04:32,274
#
# 51
# ["ZWIRNER: Fuck, he's right on us!"]
# 277.654
# 279.823
# 00:04:37,654 --> 00:04:39,823
#
# 52
# ["Oh, man, we're dead. We're fucking dead!"]
# 280.323
# 283.493
# 00:04:40,323 --> 00:04:43,493
#
# 53
# ["Control. Perps just wiped out an innocent."]
# 295.13
# 297.466
# 00:04:55,130 --> 00:04:57,466
#
# 54
# ["I'm taking them down."]
# 297.549
# 299.468
# 00:04:57,549 --> 00:04:59,468
#
# 55
# ["(SIRENS STOP)"]
# 316.526
# 317.903
# 00:05:16,526 --> 00:05:17,903
#
# 56
# ["DREDD: Bike. Activate crowd control."]
# 318.904
# 321.031
# 00:05:18,904 --> 00:05:21,031
#
# 57
# ["AUTOMATED VOICE:<i> Activated.", "Citizens, be calm.</i>"]
# 321.156
# 323.742
# 00:05:21,156 --> 00:05:23,742
#
# 58
# ["<i>Step back from the crime scene.</i>"]
# 323.825
# 325.66
# 00:05:23,825 --> 00:05:25,660
#
# 59
# ["<i>Interference carries", "an automatic five-year sentence</i>"]
# 325.744
# 329.498
# 00:05:25,744 --> 00:05:29,498
#
# 60
# ["<i>in the iso-cubes.</i>"]
# 329.581
# 330.749
# 00:05:29,581 --> 00:05:30,749
#
# 61
# ["(GUNFIRE)", "(PEOPLE CLAMORING)"]
# 337.714
# 339.758
# 00:05:37,714 --> 00:05:39,758
#
# 62
# ["ZWIRNER: Hey, fucking get out of here!"]
# 341.051
# 343.094
# 00:05:41,051 --> 00:05:43,094
#
# 63
# ["(PEOPLE SCREAMING)"]
# 344.262
# 344.469
# 00:05:44,262 --> 00:05:44,469
#
# 64
# ["(PEOPLE SCREAMING)"]
# 344.47
# 344.552
# 00:05:44,470 --> 00:05:44,552
#
# 65
# ["(PEOPLE SCREAMING)"]
# 344.553
# 345.597
# 00:05:44,553 --> 00:05:45,597
#
# 66
# ["(GUN FIRING)"]
# 350.352
# 351.436
# 00:05:50,352 --> 00:05:51,436
#
# 67
# ["(GUNFIRE CONTINUES)"]
# 356.9
# 358.276
# 00:05:56,900 --> 00:05:58,276
#
# 68
# ["Control. Paramedics to my GPS."]
# 363.281
# 365.867
# 00:06:03,281 --> 00:06:05,867
#
# 69
# ["Multiple wounded and bodies for Resyk."]
# 365.951
# 367.953
# 00:06:05,951 --> 00:06:07,953
#
# 70
# ["CONTROL:<i> Copy, Dredd.</i>"]
# 368.286
# 369.955
# 00:06:08,286 --> 00:06:09,955
#
# 71
# ["AUTOMATED VOICE:<i>", "All shoppers are reminded</i>"]
# 371.623
# 372.874
# 00:06:11,623 --> 00:06:12,874
#
# 72
# ["<i>to avoid the level 1 food courts", "until further notice.</i>"]
# 372.958
# 375.794
# 00:06:12,958 --> 00:06:15,794
#
# 73
# ["<i>Alternative refreshments can be found...</i>"]
# 375.919
# 377.712
# 00:06:15,919 --> 00:06:17,712
#
# 74
# ["(WOMAN SOBS)", "ZWIRNER: - Shut the fuck up."]
# 377.796
# 379.881
# 00:06:17,796 --> 00:06:19,881
#
# 75
# ["- Let's talk.", "- Talk about what, Judge?"]
# 397.649
# 400.569
# 00:06:37,649 --> 00:06:40,569
#
# 76
# ["Release the hostage unharmed,"]
# 402.153
# 404.573
# 00:06:42,153 --> 00:06:44,573
#
# 77
# ["and I guarantee you a sentence of life"]
# 404.656
# 406.575
# 00:06:44,656 --> 00:06:46,575
#
# 78
# ["in an iso-cube without parole."]
# 406.658
# 409.327
# 00:06:46,658 --> 00:06:49,327
#
# 79
# ["Life without parole?"]
# 409.828
# 411.329
# 00:06:49,828 --> 00:06:51,329
#
# 80
# ["That's the deal you're offering?"]
# 411.454
# 412.734
# 00:06:51,454 --> 00:06:52,734
#
# 81
# ["Only if you comply."]
# 412.747
# 414.499
# 00:06:52,747 --> 00:06:54,499
#
# 82
# ["Your crimes include multiple homicide"]
# 415.0
# 417.335
# 00:06:55,000 --> 00:06:57,335
#
# 83
# ["and the attempted murder of a judge."]
# 417.419
# 419.838
# 00:06:57,419 --> 00:06:59,838
#
# 84
# ["If you do not comply,", "the sentence is death."]
# 420.005
# 423.842
# 00:07:00,005 --> 00:07:03,842
#
# 85
# ["You aren't a very good negotiator, Judge."]
# 424.175
# 426.344
# 00:07:04,175 --> 00:07:06,344
#
# 86
# ["You know why?", "You got no fucking leverage!"]
# 426.428
# 428.68
# 00:07:06,428 --> 00:07:08,680
#
# 87
# ["(WOMAN CONTINUES SOBBING)", "- Here's the deal."]
# 428.763
# 430.599
# 00:07:08,763 --> 00:07:10,599
#
# 88
# ["You let me walk or I blow", "her fucking brains out. Okay?"]
# 430.682
# 433.476
# 00:07:10,682 --> 00:07:13,476
#
# 89
# ["Negotiation's over."]
# 436.479
# 438.148
# 00:07:16,479 --> 00:07:18,148
#
# 90
# ["What are you doing?"]
# 438.273
# 439.691
# 00:07:18,273 --> 00:07:19,691
#
# 91
# ["Didn't you hear what I said?", "I'll kill the bitch!"]
# 439.774
# 441.694
# 00:07:19,774 --> 00:07:21,694
#
# 92
# ["Yeah, I heard you, hotshot."]
# 442.652
# 444.446
# 00:07:22,652 --> 00:07:24,446
#
# 93
# ["What?"]
# 444.529
# 445.53
# 00:07:24,529 --> 00:07:25,530
#
# 94
# ["I said \"hotshot.\""]
# 445.614
# 447.616
# 00:07:25,614 --> 00:07:27,616
#
# 95
# ["(WHIMPERING)"]
# 464.049
# 465.133
# 00:07:44,049 --> 00:07:45,133
#
# 96
# ["CONTROL:<i> Control to Dredd. Come in.</i>"]
# 471.848
# 473.85
# 00:07:51,848 --> 00:07:53,850
#
# 97
# ["<i>- Is your pursuit resolved?</i>", "- Affirmative."]
# 474.351
# 477.228
# 00:07:54,351 --> 00:07:57,228
#
# 98
# ["<i>Report back to the Hall of Justice.</i>"]
# 477.312
# 478.98
# 00:07:57,312 --> 00:07:58,980
#
# 99
# ["<i>The Chief Judge wants to see you.</i>"]
# 479.064
# 481.024
# 00:07:59,064 --> 00:08:01,024
#
# 100
# ["Thank you, Judge."]
# 484.402
# 486.029
# 00:08:04,402 --> 00:08:06,029
#
# 101
# ["AUTOMATED VOICE:<i>", "The level 1 food court</i>"]
# 487.322
# 488.49
# 00:08:07,322 --> 00:08:08,490
#
# 102
# ["<i>will reopen in 30 minutes.", "Thank you for your patience.</i>"]
# 488.573
# 491.618
# 00:08:08,573 --> 00:08:11,618
#
# 103
# ["CHIEF JUDGE:<i> Cassandra Anderson.", "Twenty-one.</i>"]
# 507.008
# 509.344
# 00:08:27,008 --> 00:08:29,344
#
# 104
# ["<i>Born in a block 100 meters", "from the radiation boundary wall.</i>"]
# 510.053
# 513.765
# 00:08:30,053 --> 00:08:33,765
#
# 105
# ["<i>At age seven, she lost both parents</i>"]
# 513.89
# 515.684
# 00:08:33,890 --> 00:08:35,684
#
# 106
# ["<i>to residual-fallout cancer.</i>"]
# 515.767
# 517.977
# 00:08:35,767 --> 00:08:37,977
#
# 107
# ["<i>As is usual with orphans,</i>"]
# 518.061
# 519.521
# 00:08:38,061 --> 00:08:39,521
#
# 108
# ["she was given a Judge aptitude test", "at age nine."]
# 519.604
# 522.857
# 00:08:39,604 --> 00:08:42,857
#
# 109
# ["It classified her as unsuitable,"]
# 522.941
# 524.859
# 00:08:42,941 --> 00:08:44,859
#
# 110
# ["but she was entered into the Academy"]
# 524.943
# 526.528
# 00:08:44,943 --> 00:08:46,528
#
# 111
# ["on special instruction."]
# 526.611
# 528.279
# 00:08:46,611 --> 00:08:48,279
#
# 112
# ["In the Academy, her record was never", "better than borderline."]
# 529.28
# 532.242
# 00:08:49,280 --> 00:08:52,242
#
# 113
# ["Her final Academy score"]
# 532.367
# 533.827
# 00:08:52,367 --> 00:08:53,827
#
# 114
# ["put her three percentile", "points below a pass."]
# 533.91
# 536.413
# 00:08:53,910 --> 00:08:56,413
#
# 115
# ["So what's she doing in a uniform?"]
# 536.496
# 538.289
# 00:08:56,496 --> 00:08:58,289
#
# 116
# ["<i>- Rookie Anderson.</i>", "- Sir."]
# 544.254
# 546.005
# 00:09:04,254 --> 00:09:06,005
#
# 117
# ["<i>How many people are observing you?</i>"]
# 546.131
# 548.007
# 00:09:06,131 --> 00:09:08,007
#
# 118
# ["Two."]
# 551.428
# 552.554
# 00:09:11,428 --> 00:09:12,554
#
# 119
# ["What can you tell me", "about the person I'm with?"]
# 552.971
# 555.64
# 00:09:12,971 --> 00:09:15,640
#
# 120
# ["Male. Another Judge."]
# 556.975
# 559.978
# 00:09:16,975 --> 00:09:19,978
#
# 121
# ["<i>I can feel anger. And control. But</i>"]
# 561.98
# 567.026
# 00:09:21,980 --> 00:09:27,026
#
# 122
# ["there's something else."]
# 568.653
# 570.321
# 00:09:28,653 --> 00:09:30,321
#
# 123
# ["<i>Something behind the control. Something</i>"]
# 570.655
# 574.159
# 00:09:30,655 --> 00:09:34,159
#
# 124
# ["almost...", "- Okay, Anderson."]
# 575.66
# 578.121
# 00:09:35,660 --> 00:09:38,121
#
# 125
# ["<i>That Will do.</i>"]
# 578.83
# 580.165
# 00:09:38,830 --> 00:09:40,165
#
# 126
# ["She's a mutant."]
# 580.832
# 582.333
# 00:09:40,832 --> 00:09:42,333
#
# 127
# ["The Judges Council have chosen", "to overlook her status."]
# 582.959
# 585.503
# 00:09:42,959 --> 00:09:45,503
#
# 128
# ["So you will, too."]
# 585.837
# 587.005
# 00:09:45,837 --> 00:09:47,005
#
# 129
# ["She's the most powerful psychic"]
# 587.756
# 589.466
# 00:09:47,756 --> 00:09:49,466
#
# 130
# ["we've ever come across by a huge margin."]
# 589.549
# 591.76
# 00:09:49,549 --> 00:09:51,760
#
# 131
# ["The Judges are losing the war for the city."]
# 592.51
# 595.013
# 00:09:52,510 --> 00:09:55,013
#
# 132
# ["We believe she could be a major asset."]
# 595.096
# 597.015
# 00:09:55,096 --> 00:09:57,015
#
# 133
# ["As I said, her final score", "was only three points below a pass."]
# 597.682
# 600.977
# 00:09:57,682 --> 00:10:00,977
#
# 134
# ["It's marginal."]
# 601.06
# 602.27
# 00:10:01,060 --> 00:10:02,270
#
# 135
# ["It's not marginal. She failed."]
# 602.353
# 604.397
# 00:10:02,353 --> 00:10:04,397
#
# 136
# ["The girl's getting one more chance."]
# 604.481
# 606.274
# 00:10:04,481 --> 00:10:06,274
#
# 137
# ["I want you to take her out,", "give her one day in the field."]
# 607.984
# 610.779
# 00:10:07,984 --> 00:10:10,779
#
# 138
# ["Supervised."]
# 610.862
# 612.197
# 00:10:10,862 --> 00:10:12,197
#
# 139
# ["See if she makes the grade."]
# 612.489
# 614.032
# 00:10:12,489 --> 00:10:14,032
#
# 140
# ["Sink or swim. Chuck her in the deep end."]
# 614.783
# 617.994
# 00:10:14,783 --> 00:10:17,994
#
# 141
# ["It's all the deep end."]
# 620.455
# 622.29
# 00:10:20,455 --> 00:10:22,290
#
# 142
# ["AUTOMATED VOICE:<i> Personnel are required</i>"]
# 624.125
# 625.46
# 00:10:24,125 --> 00:10:25,460
#
# 143
# ["<i>to carry identification at all times.</i>"]
# 625.543
# 627.17
# 00:10:25,543 --> 00:10:27,170
#
# 144
# ["DREDD: A rookie judge on assessment"]
# 627.295
# 628.463
# 00:10:27,295 --> 00:10:28,463
#
# 145
# ["is likely to be involved in armed combat."]
# 628.546
# 630.381
# 00:10:28,546 --> 00:10:30,381
#
# 146
# ["One in five don't survive the first day."]
# 630.465
# 632.383
# 00:10:30,465 --> 00:10:32,383
#
# 147
# ["You may be required to carry out"]
# 632.55
# 634.26
# 00:10:32,550 --> 00:10:34,260
#
# 148
# ["on-the-spot executions of convicted felons."]
# 634.344
# 636.137
# 00:10:34,344 --> 00:10:36,137
#
# 149
# ["Yes, sir."]
# 636.221
# 637.263
# 00:10:36,221 --> 00:10:37,263
#
# 150
# ["Incorrect sentencing is an automatic fail."]
# 637.347
# 640.225
# 00:10:37,347 --> 00:10:40,225
#
# 151
# ["Disobeying a direct order", "from your assessment officer"]
# 640.308
# 642.727
# 00:10:40,308 --> 00:10:42,727
#
# 152
# ["is an automatic fail."]
# 642.811
# 644.479
# 00:10:42,811 --> 00:10:44,479
#
# 153
# ["Losing your primary weapon or having it", "taken from you is an automatic fail."]
# 644.896
# 648.691
# 00:10:44,896 --> 00:10:48,691
#
# 154
# ["Yes, sir."]
# 648.775
# 649.818
# 00:10:48,775 --> 00:10:49,818
#
# 155
# ["Are you ready, rookie?"]
# 649.901
# 651.569
# 00:10:49,901 --> 00:10:51,569
#
# 156
# ["I am."]
# 651.653
# 653.071
# 00:10:51,653 --> 00:10:53,071
#
# 157
# ["AUTOMATED VOICE:<i>", "Mandatory vehicle checks...</i>"]
# 653.238
# 654.989
# 00:10:53,238 --> 00:10:54,989
#
# 158
# ["Your assessment starts now."]
# 655.073
# 656.491
# 00:10:55,073 --> 00:10:56,491
#
# 159
# ["(DISTORTED) Ma."]
# 743.077
# 744.329
# 00:12:23,077 --> 00:12:24,329
#
# 160
# ["We got trouble."]
# 753.922
# 755.59
# 00:12:33,922 --> 00:12:35,590
#
# 161
# ["They were selling Sternhammer product", "on my level."]
# 760.845
# 764.182
# 00:12:40,845 --> 00:12:44,182
#
# 162
# ["I warned them off with a beating", "a couple of weeks ago."]
# 764.599
# 766.935
# 00:12:44,599 --> 00:12:46,935
#
# 163
# ["Guess it didn't work."]
# 767.018
# 768.186
# 00:12:47,018 --> 00:12:48,186
#
# 164
# ["You can't deal with it yourself?"]
# 768.478
# 770.021
# 00:12:48,478 --> 00:12:50,021
#
# 165
# ["I can deal with it."]
# 770.48
# 771.981
# 00:12:50,480 --> 00:12:51,981
#
# 166
# ["The question is whether you", "wanna make an example of them."]
# 772.273
# 774.554
# 00:12:52,273 --> 00:12:54,554
#
# 167
# ["Skin them. Toss them over the balcony."]
# 778.696
# 781.824
# 00:12:58,696 --> 00:13:01,824
#
# 168
# ["Hit them with a little slo-mo first?"]
# 782.367
# 784.243
# 00:13:02,367 --> 00:13:04,243
#
# 169
# ["Sure."]
# 785.662
# 786.704
# 00:13:05,662 --> 00:13:06,704
#
# 170
# ["(SCREAMING)", "- Eat this, fucker!"]
# 794.045
# 795.463
# 00:13:14,045 --> 00:13:15,463
#
# 171
# ["Hold him down!"]
# 795.88
# 797.215
# 00:13:15,880 --> 00:13:17,215
#
# 172
# ["MAN: (BREATHLESSLY)", "Please. Oh, please."]
# 798.174
# 800.176
# 00:13:18,174 --> 00:13:20,176
#
# 173
# ["(PEOPLE SCREAMING)"]
# 833.751
# 835.044
# 00:13:53,751 --> 00:13:55,044
#
# 174
# ["CONTROL:<i> Responders in", "the vicinity of Peach Trees.</i>"]
# 844.22
# 846.347
# 00:14:04,220 --> 00:14:06,347
#
# 175
# ["<i>We have a report of a triple homicide.</i>"]
# 846.431
# 848.474
# 00:14:06,431 --> 00:14:08,474
#
# 176
# ["<i>The paramedic is on site", "and is cordoning off the area.</i>"]
# 848.558
# 852.311
# 00:14:08,558 --> 00:14:12,311
#
# 177
# ["(BEEPING)"]
# 852.395
# 853.688
# 00:14:12,395 --> 00:14:13,688
#
# 178
# ["(INDISTINCT RADIO CHATTER)"]
# 853.771
# 855.606
# 00:14:13,771 --> 00:14:15,606
#
# 179
# ["DREDD: 12 serious crimes", "reported every minute."]
# 860.236
# 863.031
# 00:14:20,236 --> 00:14:23,031
#
# 180
# ["17,000 per day."]
# 863.114
# 864.532
# 00:14:23,114 --> 00:14:24,532
#
# 181
# ["We can respond to around 6%."]
# 865.116
# 867.035
# 00:14:25,116 --> 00:14:27,035
#
# 182
# ["Which 6%?"]
# 867.118
# 868.119
# 00:14:27,118 --> 00:14:28,119
#
# 183
# ["Your show, rookie.", "You tell me."]
# 868.953
# 871.122
# 00:14:28,953 --> 00:14:31,122
#
# 184
# ["ANDERSON: Peach Trees.", "Multiple homicide."]
# 872.749
# 874.751
# 00:14:32,749 --> 00:14:34,751
#
# 185
# ["Dredd to Control.", "We'll take Peach Trees."]
# 874.959
# 877.128
# 00:14:34,959 --> 00:14:37,128
#
# 186
# ["CONTROL:<i> Copy that.</i>"]
# 877.628
# 879.088
# 00:14:37,628 --> 00:14:39,088
#
# 187
# ["(RAP MUSIC PLAYING)"]
# 889.974
# 890.975
# 00:14:49,974 --> 00:14:50,975
#
# 188
# ["(WHOOPING)"]
# 891.768
# 892.769
# 00:14:51,768 --> 00:14:52,769
#
# 189
# ["(LOUD CHEERING)"]
# 897.315
# 898.649
# 00:14:57,315 --> 00:14:58,649
#
# 190
# ["GIRL: Hey, Joey,", "show us what you've got."]
# 902.445
# 904.405
# 00:15:02,445 --> 00:15:04,405
#
# 191
# ["DREDD: Okay, rookie."]
# 909.452
# 910.495
# 00:15:09,452 --> 00:15:10,495
#
# 192
# ["What do you know", "about Peach Trees?"]
# 910.578
# 912.163
# 00:15:10,578 --> 00:15:12,163
#
# 193
# ["ANDERSON: Sir. Peach Trees houses", "75,000 registered citizens."]
# 912.246
# 915.458
# 00:15:12,246 --> 00:15:15,458
#
# 194
# ["It has the highest", "crime rate in Sector 13."]
# 915.541
# 917.585
# 00:15:15,541 --> 00:15:17,585
#
# 195
# ["Unemployment rate of 96%."]
# 917.668
# 919.712
# 00:15:17,668 --> 00:15:19,712
#
# 196
# ["And more than half the", "residential levels here"]
# 919.796
# 921.637
# 00:15:19,796 --> 00:15:21,637
#
# 197
# ["are classed as slums."]
# 921.672
# 922.965
# 00:15:21,672 --> 00:15:22,965
#
# 198
# ["Rookie."]
# 926.969
# 928.096
# 00:15:26,969 --> 00:15:28,096
#
# 199
# ["Judgment."]
# 929.597
# 930.598
# 00:15:29,597 --> 00:15:30,598
#
# 200
# ["Vagrancy, three weeks, iso-cubes."]
# 930.681
# 932.6
# 00:15:30,681 --> 00:15:32,600
#
# 201
# ["But prioritize murders?"]
# 932.683
# 934.102
# 00:15:32,683 --> 00:15:34,102
#
# 202
# ["Correct. Don't be here when we get back."]
# 934.185
# 937.021
# 00:15:34,185 --> 00:15:37,021
#
# 203
# ["Yes. Thanks, Judge."]
# 937.105
# 938.731
# 00:15:37,105 --> 00:15:38,731
#
# 204
# ["AUTOMATED VOICE:", "<i>Please remain behind the security tape.</i>"]
# 940.691
# 943.361
# 00:15:40,691 --> 00:15:43,361
#
# 205
# ["So why do you wanna be a judge?"]
# 944.445
# 946.447
# 00:15:44,445 --> 00:15:46,447
#
# 206
# ["Sir. I want to protect and serve the city."]
# 946.531
# 949.242
# 00:15:46,531 --> 00:15:49,242
#
# 207
# ["To make a difference."]
# 949.325
# 950.785
# 00:15:49,325 --> 00:15:50,785
#
# 208
# ["Make a difference to a block like this?"]
# 950.868
# 953.037
# 00:15:50,868 --> 00:15:53,037
#
# 209
# ["MAN: It's yours if you want it."]
# 953.663
# 955.54
# 00:15:53,663 --> 00:15:55,540
#
# 210
# ["I was born and raised in a block like this"]
# 955.915
# 958.042
# 00:15:55,915 --> 00:15:58,042
#
# 211
# ["before the Justice Department took me."]
# 958.126
# 960.086
# 00:15:58,126 --> 00:16:00,086
#
# 212
# ["I know there are good people inside,"]
# 960.169
# 962.13
# 00:16:00,169 --> 00:16:02,130
#
# 213
# ["good families just trying to get by."]
# 962.213
# 965.174
# 00:16:02,213 --> 00:16:05,174
#
# 214
# ["Yes, I believe I can make a difference."]
# 966.634
# 968.928
# 00:16:06,634 --> 00:16:08,928
#
# 215
# ["Admirable."]
# 971.055
# 972.39
# 00:16:11,055 --> 00:16:12,390
#
# 216
# ["AUTOMATED VOICE:", "<i>The mall will be closing today at 10:00.</i>"]
# 973.683
# 975.643
# 00:16:13,683 --> 00:16:15,643
#
# 217
# ["<i>Plenty of time", "to make your purchases.</i>"]
# 975.726
# 977.77
# 00:16:15,726 --> 00:16:17,770
#
# 218
# ["DREDD: What have you got?"]
# 980.69
# 981.732
# 00:16:20,690 --> 00:16:21,732
#
# 219
# ["TJ: Three stiffs", "in a somewhat fucked-up condition."]
# 981.816
# 984.735
# 00:16:21,816 --> 00:16:24,735
#
# 220
# ["WOMAN: Oh, did you get a picture of that?"]
# 985.695
# 987.989
# 00:16:25,695 --> 00:16:27,989
#
# 221
# ["You based in Peach Trees?"]
# 988.072
# 989.323
# 00:16:28,072 --> 00:16:29,323
#
# 222
# ["Med Center, level 25."]
# 989.407
# 991.2
# 00:16:29,407 --> 00:16:31,200
#
# 223
# ["- You ID'd them?", "- Mostly."]
# 991.325
# 992.952
# 00:16:31,325 --> 00:16:32,952
#
# 224
# ["These two are registered to this block."]
# 993.035
# 994.662
# 00:16:33,035 --> 00:16:34,662
#
# 225
# ["And him?"]
# 994.745
# 995.788
# 00:16:34,745 --> 00:16:35,788
#
# 226
# ["I'll have to run his blood", "through a DNA profiler."]
# 995.872
# 998.166
# 00:16:35,872 --> 00:16:38,166
#
# 227
# ["If I can figure out which blood is his."]
# 998.249
# 1000.251
# 00:16:38,249 --> 00:16:40,251
#
# 228
# ["(PEOPLE EXCLAIMING)"]
# 1002.879
# 1004.255
# 00:16:42,879 --> 00:16:44,255
#
# 229
# ["What do you make of this, rookie?"]
# 1007.258
# 1008.579
# 00:16:47,258 --> 00:16:48,579
#
# 230
# ["I don't know, sir."]
# 1010.72
# 1011.929
# 00:16:50,720 --> 00:16:51,929
#
# 231
# ["It's a cold-burn from a slo-mo inhaler."]
# 1017.518
# 1019.52
# 00:16:57,518 --> 00:16:59,520
#
# 232
# ["Slo-mo?"]
# 1020.188
# 1021.314
# 00:17:00,188 --> 00:17:01,314
#
# 233
# ["Only just hit the grid,", "but it's making big waves."]
# 1021.731
# 1024.984
# 00:17:01,731 --> 00:17:04,984
#
# 234
# ["Makes the brain feel as if"]
# 1025.067
# 1026.277
# 00:17:05,067 --> 00:17:06,277
#
# 235
# ["time is passing at 1% its normal speed."]
# 1026.36
# 1028.863
# 00:17:06,360 --> 00:17:08,863
#
# 236
# ["Guess it felt like a long way down."]
# 1030.615
# 1032.867
# 00:17:10,615 --> 00:17:12,867
#
# 237
# ["CONTROL: Positive on your IDs."]
# 1047.256
# 1048.841
# 00:17:27,256 --> 00:17:28,841
#
# 238
# ["All showing convictions for", "possession of narcotics."]
# 1049.342
# 1052.053
# 00:17:29,342 --> 00:17:32,053
#
# 239
# ["Transmitting data now."]
# 1052.762
# 1053.888
# 00:17:32,762 --> 00:17:33,888
#
# 240
# ["Small-time perps. Junkies.", "No known gang affiliation."]
# 1055.765
# 1058.809
# 00:17:35,765 --> 00:17:38,809
#
# 241
# ["What's your analysis?"]
# 1058.893
# 1060.144
# 00:17:38,893 --> 00:17:40,144
#
# 242
# ["ANDERSON: Drugged. Skinned.", "Displayed in public."]
# 1062.104
# 1064.482
# 00:17:42,104 --> 00:17:44,482
#
# 243
# ["I think it's a punishment killing."]
# 1064.982
# 1066.901
# 00:17:44,982 --> 00:17:46,901
#
# 244
# ["Someone's trying to send a message."]
# 1066.984
# 1068.903
# 00:17:46,984 --> 00:17:48,903
#
# 245
# ["Yeah. Don't fuck with the Ma-Ma Clan."]
# 1068.986
# 1072.156
# 00:17:48,986 --> 00:17:52,156
#
# 246
# ["Ma-Ma Clan?"]
# 1073.658
# 1074.992
# 00:17:53,658 --> 00:17:54,992
#
# 247
# ["TJ: We have her", "on record from her whoring days."]
# 1078.996
# 1081.749
# 00:17:58,996 --> 00:18:01,749
#
# 248
# ["The picture's pretty old"]
# 1081.832
# 1083.709
# 00:18:01,832 --> 00:18:03,709
#
# 249
# ["but that's her.", "Madeline Madrigal, aka Ma-Ma."]
# 1083.793
# 1088.339
# 00:18:03,793 --> 00:18:08,339
#
# 250
# ["Ex-hooker from the S-9 pleasure district."]
# 1089.006
# 1091.55
# 00:18:09,006 --> 00:18:11,550
#
# 251
# ["Quit working when she got", "sliced up by her pimp."]
# 1092.343
# 1094.845
# 00:18:12,343 --> 00:18:14,845
#
# 252
# ["She got her own back."]
# 1095.137
# 1096.514
# 00:18:15,137 --> 00:18:16,514
#
# 253
# ["Block legend says", "she feminized the guy with her teeth."]
# 1096.973
# 1099.6
# 00:18:16,973 --> 00:18:19,600
#
# 254
# ["Took over his business interests", "and never looked back."]
# 1100.518
# 1104.021
# 00:18:20,518 --> 00:18:24,021
#
# 255
# ["Anyone else, you'd say", "it was bullshit, right?"]
# 1104.772
# 1107.024
# 00:18:24,772 --> 00:18:27,024
#
# 256
# ["<i>Not with Ma-Ma.", "Her trademark is violence.</i>"]
# 1108.025
# 1111.195
# 00:18:28,025 --> 00:18:31,195
#
# 257
# ["(SCREAMING)"]
# 1112.697
# 1114.031
# 00:18:32,697 --> 00:18:34,031
#
# 258
# ["<i>Not so long ago", "there were three main gangs</i>"]
# 1115.491
# 1118.119
# 00:18:35,491 --> 00:18:38,119
#
# 259
# ["<i>hustling for control of Peach Trees.</i>"]
# 1118.202
# 1120.371
# 00:18:38,202 --> 00:18:40,371
#
# 260
# ["The Peyote Kings,", "the Red Dragons, the Judged."]
# 1120.997
# 1124.709
# 00:18:40,997 --> 00:18:44,709
#
# 261
# ["<i>Then Ma-Ma arrived.</i>"]
# 1125.501
# 1126.877
# 00:18:45,501 --> 00:18:46,877
#
# 262
# ["(GUN FIRES)"]
# 1127.378
# 1128.379
# 00:18:47,378 --> 00:18:48,379
#
# 263
# ["MAN 1: What the fuck?"]
# 1133.342
# 1134.385
# 00:18:53,342 --> 00:18:54,385
#
# 264
# ["MAN 2: Let's go!"]
# 1136.387
# 1137.638
# 00:18:56,387 --> 00:18:57,638
#
# 265
# ["TJ:<i> Took over the top floor of the block</i>"]
# 1139.307
# 1140.908
# 00:18:59,307 --> 00:19:00,908
#
# 266
# ["<i>and started working her way down.</i>"]
# 1140.975
# 1142.727
# 00:19:00,975 --> 00:19:02,727
#
# 267
# ["Nine months later,", "she had control of everything."]
# 1144.562
# 1147.898
# 00:19:04,562 --> 00:19:07,898
#
# 268
# ["Levels 1 to 200"]
# 1148.065
# 1150.318
# 00:19:08,065 --> 00:19:10,318
#
# 269
# ["<i>are hers.</i>"]
# 1151.152
# 1152.486
# 00:19:11,152 --> 00:19:12,486
#
# 270
# ["How did she get away with it?"]
# 1153.404
# 1154.739
# 00:19:13,404 --> 00:19:14,739
#
# 271
# ["You know how often we get", "a judge up in Peach Trees?"]
# 1154.822
# 1158.075
# 00:19:14,822 --> 00:19:18,075
#
# 272
# ["Well, you got one now."]
# 1158.993
# 1160.619
# 00:19:18,993 --> 00:19:20,619
#
# 273
# ["The victims are registered", "to apartments on level 39."]
# 1161.912
# 1165.416
# 00:19:21,912 --> 00:19:25,416
#
# 274
# ["Likely killed over a turf issue,"]
# 1165.75
# 1167.46
# 00:19:25,750 --> 00:19:27,460
#
# 275
# ["so perps will be in the vicinity."]
# 1167.71
# 1169.67
# 00:19:27,710 --> 00:19:29,670
#
# 276
# ["Rookie."]
# 1171.422
# 1172.715
# 00:19:31,422 --> 00:19:32,715
#
# 277
# ["Find out where the Clan", "operate on this level, and hit it hard."]
# 1173.215
# 1176.427
# 00:19:33,215 --> 00:19:36,427
#
# 278
# ["DREDD: That would be here."]
# 1180.181
# 1181.599
# 00:19:40,181 --> 00:19:41,599
#
# 279
# ["(INDISTINCT SHOUTING)"]
# 1190.649
# 1192.151
# 00:19:50,649 --> 00:19:52,151
#
# 280
# ["(KNOCKING)"]
# 1196.405
# 1197.448
# 00:19:56,405 --> 00:19:57,448
#
# 281
# ["(LOUD MUSIC PLAYING)"]
# 1197.531
# 1198.949
# 00:19:57,531 --> 00:19:58,949
#
# 282
# ["(MUFFLED MUSIC ECHOING)"]
# 1232.9
# 1235.444
# 00:20:32,900 --> 00:20:35,444
#
# 283
# ["Take it this is", "your first time in non-sim combat."]
# 1250.835
# 1253.087
# 00:20:50,835 --> 00:20:53,087
#
# 284
# ["Yes, sir."]
# 1253.17
# 1254.588
# 00:20:53,170 --> 00:20:54,588
#
# 285
# ["Been wondering when you'd remember"]
# 1254.672
# 1256.34
# 00:20:54,672 --> 00:20:56,340
#
# 286
# ["you left your helmet behind."]
# 1256.424
# 1257.967
# 00:20:56,424 --> 00:20:57,967
#
# 287
# ["Sir, a helmet can interfere", "with my psychic abilities."]
# 1258.092
# 1261.053
# 00:20:58,092 --> 00:21:01,053
#
# 288
# ["Think a bullet might", "interfere with them more."]
# 1262.471
# 1264.807
# 00:21:02,471 --> 00:21:04,807
#
# 289
# ["(BEEPS)"]
# 1272.69
# 1273.691
# 00:21:12,690 --> 00:21:13,691
#
# 290
# ["Are you ready?"]
# 1276.444
# 1277.653
# 00:21:16,444 --> 00:21:17,653
#
# 291
# ["Yes, sir."]
# 1277.736
# 1278.863
# 00:21:17,736 --> 00:21:18,863
#
# 292
# ["You don't look ready."]
# 1280.698
# 1282.116
# 00:21:20,698 --> 00:21:22,116
#
# 293
# ["Just adrenaline, sir."]
# 1282.199
# 1283.868
# 00:21:22,199 --> 00:21:23,868
#
# 294
# ["(LOUD MUSIC PLAYING)"]
# 1287.496
# 1288.706
# 00:21:27,496 --> 00:21:28,706
#
# 295
# ["(RAPID BEEPING)"]
# 1289.707
# 1290.749
# 00:21:29,707 --> 00:21:30,749
#
# 296
# ["DREDD: Rookie."]
# 1362.363
# 1363.447
# 00:22:42,363 --> 00:22:43,447
#
# 297
# ["Anderson. Judgment."]
# 1365.199
# 1366.825
# 00:22:45,199 --> 00:22:46,825
#
# 298
# ["Crime, possession and use", "of controlled substances."]
# 1367.785
# 1370.12
# 00:22:47,785 --> 00:22:50,120
#
# 299
# ["Sentence: two years iso-cubes."]
# 1370.204
# 1372.289
# 00:22:50,204 --> 00:22:52,289
#
# 300
# ["No, don't tell me. Tell Control."]
# 1373.29
# 1375.209
# 00:22:53,290 --> 00:22:55,209
#
# 301
# ["Anderson to Control."]
# 1377.086
# 1378.212
# 00:22:57,086 --> 00:22:58,212
#
# 302
# ["CONTROL: <i>Copy.</i>"]
# 1378.295
# 1379.338
# 00:22:58,295 --> 00:22:59,338
#
# 303
# ["Requesting meat wagon to", "Peach Trees, level 39."]
# 1379.421
# 1381.715
# 00:22:59,421 --> 00:23:01,715
#
# 304
# ["We have"]
# 1381.799
# 1383.008
# 00:23:01,799 --> 00:23:03,008
#
# 305
# ["four bodies for Resyk", "and eight live for the iso-cubes."]
# 1383.092
# 1386.679
# 00:23:03,092 --> 00:23:06,679
#
# 306
# ["<i>Copy that. Meat wagon inbound.</i>"]
# 1386.762
# 1388.764
# 00:23:06,762 --> 00:23:08,764
#
# 307
# ["All right. Let's get them cuffed."]
# 1389.473
# 1391.308
# 00:23:09,473 --> 00:23:11,308
#
# 308
# ["Move. Up."]
# 1391.809
# 1392.851
# 00:23:11,809 --> 00:23:12,851
#
# 309
# ["(GRUNTS)"]
# 1395.145
# 1396.146
# 00:23:15,145 --> 00:23:16,146
#
# 310
# ["Sir, this one's a gang member. He..."]
# 1400.15
# 1402.361
# 00:23:20,150 --> 00:23:22,361
#
# 311
# ["Sir, it's him."]
# 1409.451
# 1411.036
# 00:23:29,451 --> 00:23:31,036
#
# 312
# ["Him who?"]
# 1411.12
# 1412.746
# 00:23:31,120 --> 00:23:32,746
#
# 313
# ["The man who murdered", "the people in the atrium."]
# 1412.83
# 1414.631
# 00:23:32,830 --> 00:23:34,631
#
# 314
# ["You're sure?"]
# 1416.667
# 1417.668
# 00:23:36,667 --> 00:23:37,668
#
# 315
# ["99%."]
# 1420.629
# 1421.88
# 00:23:40,629 --> 00:23:41,880
#
# 316
# ["Can't execute a perp on 99%."]
# 1425.009
# 1427.636
# 00:23:45,009 --> 00:23:47,636
#
# 317
# ["Save me a lot of paperwork", "if you just confess right now."]
# 1432.182
# 1435.894
# 00:23:52,182 --> 00:23:55,894
#
# 318
# ["We'll take him in."]
# 1439.356
# 1441.483
# 00:23:59,356 --> 00:24:01,483
#
# 319
# ["See how he holds up", "after a few hours of interrogation."]
# 1441.567
# 1444.445
# 00:24:01,567 --> 00:24:04,445
#
# 320
# ["(LIGHT ROCK MUSIC PLAYING)"]
# 1450.326
# 1452.661
# 00:24:10,326 --> 00:24:12,661
#
# 321
# ["Oh, shit."]
# 1471.18
# 1472.389
# 00:24:31,180 --> 00:24:32,389
#
# 322
# ["Judges. No, no, no..."]
# 1474.183
# 1476.852
# 00:24:34,183 --> 00:24:36,852
#
# 323
# ["Uh, Caleb?", "There's a problem on level 39."]
# 1479.355
# 1483.067
# 00:24:39,355 --> 00:24:43,067
#
# 324
# ["CALEB: Judges hit the distribution point", "and shot the place up."]
# 1483.4
# 1485.88
# 00:24:43,400 --> 00:24:45,880
#
# 325
# ["Took out a few of the boys."]
# 1485.944
# 1487.446
# 00:24:45,944 --> 00:24:47,446
#
# 326
# ["So what? We're overdue a bust."]
# 1487.529
# 1489.239
# 00:24:47,529 --> 00:24:49,239
#
# 327
# ["It's just the judges showing their faces,"]
# 1489.406
# 1490.658
# 00:24:49,406 --> 00:24:50,658
#
# 328
# ["reminding the citizens they exist."]
# 1490.741
# 1492.242
# 00:24:50,741 --> 00:24:52,242
#
# 329
# ["No, Ma. They picked up Kay."]
# 1492.326
# 1494.203
# 00:24:52,326 --> 00:24:54,203
#
# 330
# ["Executed?"]
# 1494.286
# 1495.329
# 00:24:54,286 --> 00:24:55,329
#
# 331
# ["Interrogation.", "They're taking him in right now."]
# 1495.412
# 1497.706
# 00:24:55,412 --> 00:24:57,706
#
# 332
# ["Fuck."]
# 1497.79
# 1498.791
# 00:24:57,790 --> 00:24:58,791
#
# 333
# ["If Kay talks..."]
# 1499.333
# 1500.417
# 00:24:59,333 --> 00:25:00,417
#
# 334
# ["If they're taking him in, he'll talk."]
# 1500.584
# 1502.878
# 00:25:00,584 --> 00:25:02,878
#
# 335
# ["What are we gonna do?"]
# 1505.506
# 1506.757
# 00:25:05,506 --> 00:25:06,757
#
# 336
# ["(GUN SHOTS)"]
# 1533.784
# 1534.952
# 00:25:33,784 --> 00:25:34,952
#
# 337
# ["CALEB: That one's still breathing."]
# 1538.455
# 1540.29
# 00:25:38,455 --> 00:25:40,290
#
# 338
# ["Control room is secure."]
# 1543.46
# 1544.92
# 00:25:43,460 --> 00:25:44,920
#
# 339
# ["Router's in. You're good to go."]
# 1552.469
# 1554.638
# 00:25:52,469 --> 00:25:54,638
#
# 340
# ["OPERATOR:<i> Sector Control.</i>"]
# 1557.808
# 1559.268
# 00:25:57,808 --> 00:25:59,268
#
# 341
# ["Sector Control. This is", "Peach Tree's control."]
# 1560.31
# 1562.396
# 00:26:00,310 --> 00:26:02,396
#
# 342
# ["I just wanna check you were notified about"]
# 1562.479
# 1564.064
# 00:26:02,479 --> 00:26:04,064
#
# 343
# ["the def-con systems test today."]
# 1564.148
# 1566.15
# 00:26:04,148 --> 00:26:06,150
#
# 344
# ["<i>Copy that.</i>"]
# 1566.233
# 1567.735
# 00:26:06,233 --> 00:26:07,735
#
# 345
# ["<i>Peach Trees, we don't have", "you down for a def-con test.</i>"]
# 1567.818
# 1569.82
# 00:26:07,818 --> 00:26:09,820
#
# 346
# ["Yeah, we must be. If you check the..."]
# 1569.903
# 1571.572
# 00:26:09,903 --> 00:26:11,572
#
# 347
# ["<i>I've got nothing.</i>"]
# 1571.655
# 1572.99
# 00:26:11,655 --> 00:26:12,990
#
# 348
# ["God fucking damn it, Sector!"]
# 1575.993
# 1577.786
# 00:26:15,993 --> 00:26:17,786
#
# 349
# ["I put in the notification", "myself three fucking times!"]
# 1577.87
# 1581.206
# 00:26:17,870 --> 00:26:21,206
#
# 350
# ["We are good to go right now!"]
# 1581.498
# 1582.75
# 00:26:21,498 --> 00:26:22,750
#
# 351
# ["I've got my supervisor", "breathing down my neck."]
# 1582.833
# 1586.253
# 00:26:22,833 --> 00:26:26,253
#
# 352
# ["<i>Hold fire, Peach Trees.", "Let me get on this.</i>"]
# 1586.336
# 1588.672
# 00:26:26,336 --> 00:26:28,672
#
# 353
# ["<i>Okay. I put you on the system.</i>"]
# 1589.339
# 1591.55
# 00:26:29,339 --> 00:26:31,550
#
# 354
# ["<i>Hall of Justice and all emergency services</i>"]
# 1591.633
# 1593.677
# 00:26:31,633 --> 00:26:33,677
#
# 355
# ["<i>are notified to ignore your status.</i>"]
# 1593.761
# 1595.429
# 00:26:33,761 --> 00:26:35,429
#
# 356
# ["<i>You can run the test any time you like.</i>"]
# 1595.512
# 1597.681
# 00:26:35,512 --> 00:26:37,681
#
# 357
# ["Appreciate that, Sector."]
# 1597.848
# 1599.391
# 00:26:37,848 --> 00:26:39,391
#
# 358
# ["You just saved my ass over here."]
# 1599.641
# 1601.685
# 00:26:39,641 --> 00:26:41,685
#
# 359
# ["<i>You're welcome, Peach Trees.</i>"]
# 1602.019
# 1603.52
# 00:26:42,019 --> 00:26:43,520
#
# 360
# ["Sir, he's thinking about", "making a move for your gun."]
# 1613.363
# 1615.991
# 00:26:53,363 --> 00:26:55,991
#
# 361
# ["DREDD: Yeah."]
# 1616.7
# 1617.868
# 00:26:56,700 --> 00:26:57,868
#
# 362
# ["He just changed his mind."]
# 1619.036
# 1620.996
# 00:26:59,036 --> 00:27:00,996
#
# 363
# ["Yeah."]
# 1621.497
# 1622.498
# 00:27:01,497 --> 00:27:02,498
#
# 364
# ["CLAN TECHIE: <i>Then enter the pass key</i>"]
# 1627.461
# 1629.129
# 00:27:07,461 --> 00:27:09,129
#
# 365
# ["<i>and you should be inside.</i>"]
# 1629.213
# 1630.672
# 00:27:09,213 --> 00:27:10,672
#
# 366
# ["AUTOMATED VOICE:", "<i>Security protocols accessed.</i>"]
# 1633.217
# 1635.219
# 00:27:13,217 --> 00:27:15,219
#
# 367
# ["<i>War protocol accessed.</i>"]
# 1636.72
# 1638.514
# 00:27:16,720 --> 00:27:18,514
#
# 368
# ["<i>Blast shield initiated.</i>"]
# 1640.057
# 1641.85
# 00:27:20,057 --> 00:27:21,850
# 369
# ["Warned you. Get up.", "You're headed for the cubes."]
# 1647.523
# 1650.067
# 00:27:27,523 --> 00:27:30,067
#
# 370
# ["AUTOMATED VOICE: <i>Stand clear of doors.</i>"]
# 1650.15
# 1651.67
# 00:27:30,150 --> 00:27:31,670
#
# 371
# ["(ALARM BLARING)"]
# 1651.735
# 1653.028
# 00:27:31,735 --> 00:27:33,028
#
# 372
# ["<i>All residents remain calm.</i>"]
# 1655.155
# 1657.366
# 00:27:35,155 --> 00:27:37,366
#
# 373
# ["<i>All residents remain calm.</i>"]
# 1659.743
# 1661.829
# 00:27:39,743 --> 00:27:41,829
#
# 374
# ["<i>All residents remain calm.</i>"]
# 1663.747
# 1665.457
# 00:27:43,747 --> 00:27:45,457
#
# 375
# ["(PEOPLE TALKING INDISTINCTLY)"]
# 1684.518
# 1687.771
# 00:28:04,518 --> 00:28:07,771
#
# 376
# ["What's going on?"]
# 1698.198
# 1699.449
# 00:28:18,198 --> 00:28:19,449
#
# 377
# ["AUTOMATED VOICE: <i>Lockdown complete.</i>"]
# 1708.375
# 1710.294
# 00:28:28,375 --> 00:28:30,294
#
# 378
# ["You're patched in."]
# 1723.098
# 1724.766
# 00:28:43,098 --> 00:28:44,766
#
# 379
# ["Peach Trees."]
# 1740.657
# 1741.909
# 00:29:00,657 --> 00:29:01,909
#
# 380
# ["<i>This is Ma-Ma.</i>"]
# 1742.993
# 1744.328
# 00:29:02,993 --> 00:29:04,328
#
# 381
# ["(FEEDBACK WHINING)"]
# 1745.287
# 1746.496
# 00:29:05,287 --> 00:29:06,496
#
# 382
# ["<i>Somewhere in this block are two judges.</i>"]
# 1748.081
# 1750.584
# 00:29:08,081 --> 00:29:10,584
#
# 383
# ["<i>I want them dead.</i>"]
# 1753.17
# 1754.546
# 00:29:13,170 --> 00:29:14,546
#
# 384
# ["<i>Until I get what I want,", "the block is locked down.</i>"]
# 1756.632
# 1759.176
# 00:29:16,632 --> 00:29:19,176
#
# 385
# ["<i>All Clan, every level,", "hunt the judges down.</i>"]
# 1761.678
# 1765.557
# 00:29:21,678 --> 00:29:25,557
#
# 386
# ["Everyone else, clear the corridors"]
# 1767.267
# 1769.102
# 00:29:27,267 --> 00:29:29,102
#
# 387
# ["and stay the fuck out of our way", "until the shooting stops."]
# 1769.186
# 1771.772
# 00:29:29,186 --> 00:29:31,772
#
# 388
# ["(ALL CLAMORING)"]
# 1772.022
# 1773.357
# 00:29:32,022 --> 00:29:33,357
#
# 389
# ["<i>If I hear of anyone helping the judges,</i>"]
# 1775.525
# 1777.235
# 00:29:35,525 --> 00:29:37,235
#
# 390
# ["<i>I will kill them and the next", "generation of their family.</i>"]
# 1777.319
# 1780.53
# 00:29:37,319 --> 00:29:40,530
#
# 391
# ["<i>As for the judges...</i>"]
# 1787.371
# 1789.289
# 00:29:47,371 --> 00:29:49,289
#
# 392
# ["We better move."]
# 1789.373
# 1791.124
# 00:29:49,373 --> 00:29:51,124
#
# 393
# ["<i>...sit tight, or run.</i>"]
# 1791.208
# 1793.543
# 00:29:51,208 --> 00:29:53,543
#
# 394
# ["Makes no difference. You're mine."]
# 1797.339
# 1799.549
# 00:29:57,339 --> 00:29:59,549
#
# 395
# ["(CHILD CRYING)"]
# 1809.017
# 1810.227
# 00:30:09,017 --> 00:30:10,227
#
# 396
# ["DREDD: Control, we have a situation"]
# 1818.86
# 1820.153
# 00:30:18,860 --> 00:30:20,153
#
# 397
# ["developing in Peach Trees.", "Do you copy?"]
# 1820.237
# 1822.239
# 00:30:20,237 --> 00:30:22,239
#
# 398
# ["(STATIC ON RADIO)"]
# 1822.322
# 1823.573
# 00:30:22,322 --> 00:30:23,573
#
# 399
# ["Control, do you copy?"]
# 1824.241
# 1825.826
# 00:30:24,241 --> 00:30:25,826
#
# 400
# ["My comms are down too."]
# 1825.909
# 1827.619
# 00:30:25,909 --> 00:30:27,619
#
# 401
# ["Shielding must be blocking", "our transmissions."]
# 1827.703
# 1829.579
# 00:30:27,703 --> 00:30:29,579
#
# 402
# ["We'll head for the Med Center."]
# 1830.58
# 1832.332
# 00:30:30,580 --> 00:30:32,332
#
# 403
# ["(MEN SHOUTING)"]
# 1832.416
# 1833.583
# 00:30:32,416 --> 00:30:33,583
#
# 404
# ["CLAN MEMBER: They're here!"]
# 1837.379
# 1838.755
# 00:30:37,379 --> 00:30:38,755
#
# 405
# ["- Call it.", "- Sir?"]
# 1840.34
# 1841.633
# 00:30:40,340 --> 00:30:41,633
#
# 406
# ["You're on assessment, Rookie. Call it."]
# 1841.717
# 1843.552
# 00:30:41,717 --> 00:30:43,552
#
# 407
# ["Multiple armed targets.", "Obstructed line of sight."]
# 1844.928
# 1846.513
# 00:30:44,928 --> 00:30:46,513
#
# 408
# ["- Gas grenades.", "- Respirators."]
# 1846.596
# 1848.098
# 00:30:46,596 --> 00:30:48,098
#
# 409
# ["Advise you hold your breath."]
# 1850.183
# 1851.685
# 00:30:50,183 --> 00:30:51,685
#
# 410
# ["(MEN COUGHING)"]
# 1865.615
# 1867.2
# 00:31:05,615 --> 00:31:07,200
#
# 411
# ["(GRUNTING)"]
# 1881.048
# 1882.049
# 00:31:21,048 --> 00:31:22,049
#
# 412
# ["(ELEVATOR DINGS)"]
# 1893.435
# 1894.561
# 00:31:33,435 --> 00:31:34,561
#
# 413
# ["I want the North and East", "corridor totally covered."]
# 1911.244
# 1914.414
# 00:31:51,244 --> 00:31:54,414
#
# 414
# ["Sal's got the West and the South."]
# 1914.498
# 1916.249
# 00:31:54,498 --> 00:31:56,249
#
# 415
# ["And spread out your hardware."]
# 1916.666
# 1918.168
# 00:31:56,666 --> 00:31:58,168
#
# 416
# ["We're gonna hand these judges", "back to Ma-Ma on a plate."]
# 1918.752
# 1921.505
# 00:31:58,752 --> 00:32:01,505
#
# 417
# ["(INDISTINCT SHOUTING)"]
# 1924.174
# 1925.509
# 00:32:04,174 --> 00:32:05,509
#
# 418
# ["BIG JOE: Stay fucking focused."]
# 1926.176
# 1928.095
# 00:32:06,176 --> 00:32:08,095
#
# 419
# ["CLAN MEMBER 1: Judges got it coming!"]
# 1928.178
# 1930.18
# 00:32:08,178 --> 00:32:10,180
#
# 420
# ["(MEN TALKING INDISTINCTLY)"]
# 1933.934
# 1935.352
# 00:32:13,934 --> 00:32:15,352
#
# 421
# ["CLAN MEMBER 2: Judge, come and get me."]
# 1941.942
# 1943.462
# 00:32:21,942 --> 00:32:23,462
#
# 422
# ["We're gonna have to go through them."]
# 1943.527
# 1945.654
# 00:32:23,527 --> 00:32:25,654
#
# 423
# ["Stun grenade."]
# 1947.03
# 1948.615
# 00:32:27,030 --> 00:32:28,615
#
# 424
# ["CLAN MEMBER 3: Kill that motherfucker."]
# 1952.661
# 1954.621
# 00:32:32,661 --> 00:32:34,621
#
# 425
# ["Let's give them the good news."]
# 1954.704
# 1956.414
# 00:32:34,704 --> 00:32:36,414
#
# 426
# ["CLAN MEMBER 1: Man up that corridor, man."]
# 1961.878
# 1964.131
# 00:32:41,878 --> 00:32:44,131
#
# 427
# ["CLAN MEMBER 2: Fuck up the judges."]
# 1964.214
# 1965.423
# 00:32:44,214 --> 00:32:45,423
#
# 428
# ["Fuck them."]
# 1965.507
# 1966.8
# 00:32:45,507 --> 00:32:46,800
#
# 429
# ["Citizens of Peach Trees. This is the law."]
# 1966.883
# 1970.554
# 00:32:46,883 --> 00:32:50,554
#
# 430
# ["CLAN MEMBER 3: Who do you think you are", "coming up in here?"]
# 1970.679
# 1972.556
# 00:32:50,679 --> 00:32:52,556
#
# 431
# ["Disperse immediately,"]
# 1972.889
# 1974.349
# 00:32:52,889 --> 00:32:54,349
#
# 432
# ["or we will use lethal", "force to clear the area."]
# 1974.432
# 1977.269
# 00:32:54,432 --> 00:32:57,269
#
# 433
# ["CLAN MEMBER 1: Where's that coming from?"]
# 1977.435
# 1978.562
# 00:32:57,435 --> 00:32:58,562
#
# 434
# ["Over there. Access corridor."]
# 1978.812
# 1980.856
# 00:32:58,812 --> 00:33:00,856
#
# 435
# ["DREDD: (OVER PA) <i>You have been warned.</i>"]
# 1981.481
# 1983.567
# 00:33:01,481 --> 00:33:03,567
#
# 436
# ["You now have 20 seconds to comply."]
# 1984.734
# 1987.404
# 00:33:04,734 --> 00:33:07,404
#
# 437
# ["It's you doing the complying, Judge."]
# 1987.821
# 1989.781
# 00:33:07,821 --> 00:33:09,781
#
# 438
# ["There's 10 of us, only two of you."]
# 1990.24
# 1992.492
# 00:33:10,240 --> 00:33:12,492
#
# 439
# ["Why don't you step out", "from behind that doorway"]
# 1993.41
# 1995.412
# 00:33:13,410 --> 00:33:15,412
#
# 440
# ["or we're gonna blow the fuck out of you."]
# 1995.537
# 1996.913
# 00:33:15,537 --> 00:33:16,913
#
# 441
# ["Ten seconds to comply."]
# 1997.038
# 1998.707
# 00:33:17,038 --> 00:33:18,707
#
# 442
# ["JAPHET: - Fuck you, Judge.", "- You got five."]
# 1999.04
# 2001.251
# 00:33:19,040 --> 00:33:21,251
#
# 443
# ["Thanks for the heads-up."]
# 2002.085
# 2003.545
# 00:33:22,085 --> 00:33:23,545
#
# 444
# ["(GUNFIRE)"]
# 2008.508
# 2009.593
# 00:33:28,508 --> 00:33:29,593
#
# 445
# ["(MUFFLED SCREAMING)"]
# 2012.429
# 2015.098
# 00:33:32,429 --> 00:33:35,098
#
# 446
# ["(SPUTTERING)"]
# 2019.06
# 2020.937
# 00:33:39,060 --> 00:33:40,937
#
# 447
# ["Please."]
# 2023.44
# 2024.566
# 00:33:43,440 --> 00:33:44,566
#
# 448
# ["What are you waiting for, rookie?"]
# 2025.775
# 2027.527
# 00:33:45,775 --> 00:33:47,527
#
# 449
# ["His crime is attempted murder of a Judge."]
# 2027.903
# 2030.03
# 00:33:47,903 --> 00:33:50,030
#
# 450
# ["His sentence is death."]
# 2030.113
# 2031.823
# 00:33:50,113 --> 00:33:51,823
#
# 451
# ["Yes, sir."]
# 2034.117
# 2035.285
# 00:33:54,117 --> 00:33:55,285
#
# 452
# ["(INTERCOM BEEPING)"]
# 2060.685
# 2061.895
# 00:34:20,685 --> 00:34:21,895
#
# 453
# ["Open up."]
# 2061.978
# 2063.313
# 00:34:21,978 --> 00:34:23,313
#
# 454
# ["<i>Open Up!</i>"]
# 2064.481
# 2065.607
# 00:34:24,481 --> 00:34:25,607
#
# 455
# ["<i>Negative, Judge.</i>"]
# 2067.067
# 2068.151
# 00:34:27,067 --> 00:34:28,151
#
# 456
# ["<i>You know what's going on out here.</i>"]
# 2068.318
# 2070.028
# 00:34:28,318 --> 00:34:30,028
#
# 457
# ["We need a place we can defend."]
# 2070.237
# 2071.696
# 00:34:30,237 --> 00:34:31,696
#
# 458
# ["<i>Then you better find someplace else.</i>"]
# 2071.78
# 2073.448
# 00:34:31,780 --> 00:34:33,448
#
# 459
# ["<i>This is a medical facility. Neutral ground.</i>"]
# 2073.531
# 2075.659
# 00:34:33,531 --> 00:34:35,659
#
# 460
# ["Neutral? You're not neutral.", "You're choosing sides."]
# 2075.825
# 2079.329
# 00:34:35,825 --> 00:34:39,329
# 461
# ["<i>Peach Trees has been sealed by blast doors</i>"]
# 2079.663
# 2081.343
# 00:34:39,663 --> 00:34:41,343
#
# 462
# ["<i>designed to withstand attack.</i>"]
# 2081.373
# 2082.958
# 00:34:41,373 --> 00:34:42,958
#
# 463
# ["<i>No one's getting out. No one's coming in.</i>"]
# 2083.041
# 2085.252
# 00:34:43,041 --> 00:34:45,252
#
# 464
# ["<i>And you have every clan affiliate", "in the block after your blood.</i>"]
# 2085.752
# 2088.838
# 00:34:45,752 --> 00:34:48,838
#
# 465
# ["There are no sides. You're already dead."]
# 2089.798
# 2092.926
# 00:34:49,798 --> 00:34:52,926
#
# 466
# ["(INTERCOM CUTS OUT)"]
# 2095.011
# 2096.304
# 00:34:55,011 --> 00:34:56,304
#
# 467
# ["DREDD: Looks like", "the Med Center's closed early today."]
# 2113.53
# 2116.199
# 00:35:13,530 --> 00:35:16,199
#
# 468
# ["Switch weapon to silencer mode."]
# 2116.7
# 2118.368
# 00:35:16,700 --> 00:35:18,368
#
# 469
# ["Our best bet now is to go covert."]
# 2118.702
# 2120.704
# 00:35:18,702 --> 00:35:20,704
#
# 470
# ["Conserve ammunition."]
# 2121.204
# 2122.706
# 00:35:21,204 --> 00:35:22,706
#
# 471
# ["And don't shoot unless you're gonna hit."]
# 2123.206
# 2125.041
# 00:35:23,206 --> 00:35:25,041
#
# 472
# ["Sir, what about the prisoner?"]
# 2127.627
# 2129.17
# 00:35:27,627 --> 00:35:29,170
#
# 473
# ["Explain."]
# 2129.796
# 2130.797
# 00:35:29,796 --> 00:35:30,797
#
# 474
# ["Under the circumstances,", "he could be a liability."]
# 2131.214
# 2133.633
# 00:35:31,214 --> 00:35:33,633
#
# 475
# ["Also a prime suspect in three homicides."]
# 2133.967
# 2136.052
# 00:35:33,967 --> 00:35:36,052
#
# 476
# ["What do you say, rookie?", "Wanna out him loose?"]
# 2138.388
# 2141.558
# 00:35:38,388 --> 00:35:41,558
#
# 477
# ["No, sir."]
# 2142.809
# 2143.893
# 00:35:42,809 --> 00:35:43,893
#
# 478
# ["Get up!"]
# 2156.364
# 2157.699
# 00:35:56,364 --> 00:35:57,699
#
# 479
# ["Go, go, go, go!"]
# 2177.969
# 2179.804
# 00:36:17,969 --> 00:36:19,804
#
# 480
# ["Hold up."]
# 2199.032
# 2200.158
# 00:36:39,032 --> 00:36:40,158
#
# 481
# ["(INDISTINCT VOICES)"]
# 2213.797
# 2214.881
# 00:36:53,797 --> 00:36:54,881
#
# 482
# ["Move!"]
# 2214.964
# 2216.049
# 00:36:54,964 --> 00:36:56,049
#
# 483
# ["CLAN MEMBER 1: Keep your eyes peeled."]
# 2216.132
# 2217.967
# 00:36:56,132 --> 00:36:57,967
#
# 484
# ["CLAN MEMBER 2:", "Man, stop telling me what to fucking do!"]
# 2218.051
# 2220.212
# 00:36:58,051 --> 00:37:00,212
#
# 485
# ["CLAN MEMBER 3:", "I know that new shit..."]
# 2230.939
# 2232.982
# 00:37:10,939 --> 00:37:12,982
#
# 486
# ["(BUZZES)"]
# 2237.695
# 2238.78
# 00:37:17,695 --> 00:37:18,780
#
# 487
# ["(WHISPERS) Cathy?"]
# 2240.532
# 2241.658
# 00:37:20,532 --> 00:37:21,658
#
# 488
# ["CATHY: <i>- Who's there?</i>", "- Cathy, open the door."]
# 2242.534
# 2244.619
# 00:37:22,534 --> 00:37:24,619
#
# 489
# ["(MUFFLED GRUNTING)"]
# 2247.789
# 2249.249
# 00:37:27,789 --> 00:37:29,249
#
# 490
# ["We're not gonna hurt you."]
# 2252.001
# 2253.503
# 00:37:32,001 --> 00:37:33,503
#
# 491
# ["(BREATHING FRANTICALLY)"]
# 2254.045
# 2255.422
# 00:37:34,045 --> 00:37:35,422
#
# 492
# ["Clear."]
# 2268.476
# 2269.477
# 00:37:48,476 --> 00:37:49,477
#
# 493
# ["Secure the woman somewhere", "she can't raise any alarms."]
# 2270.687
# 2272.807
# 00:37:50,687 --> 00:37:52,807
#
# 494
# ["We can't."]
# 2274.149
# 2275.316
# 00:37:54,149 --> 00:37:55,316
#
# 495
# ["She has a baby. Asleep in the next room."]
# 2276.443
# 2279.946
# 00:37:56,443 --> 00:37:59,946
#
# 496
# ["We can't secure her if we don't know", "when she'll be freed."]
# 2280.864
# 2282.866
# 00:38:00,864 --> 00:38:02,866
#
# 497
# ["DREDD: Is there a father?"]
# 2283.116
# 2284.617
# 649
# ["You aren't cuffed, if you don't wanna be."]
# 3187.311
# 3189.438
# 00:53:07,311 --> 00:53:09,438
#
# 650
# ["(GASPS)"]
# 3190.898
# 3191.94
# 00:53:10,898 --> 00:53:11,940
#
# 651
# ["My head. Do what I like?"]
# 3195.611
# 3198.03
# 00:53:15,611 --> 00:53:18,030
#
# 652
# ["Sure."]
# 3198.113
# 3199.198
# 00:53:18,113 --> 00:53:19,198
#
# 653
# ["ANDERSON:<i> Thinking about hurting", "me doesn't actually hurt me.</i>"]
# 3203.118
# 3206.205
# 00:53:23,118 --> 00:53:26,205
#
# 654
# ["KAY:<i> Yeah. Points to you.</i>"]
# 3206.288
# 3208.457
# 00:53:26,288 --> 00:53:28,457
#
# 655
# ["<i>Except there is that thing.</i>"]
# 3209.333
# 3212.419
# 00:53:29,333 --> 00:53:32,419
#
# 656
# ["<i>What thing was that?</i>"]
# 3213.128
# 3214.63
# 00:53:33,128 --> 00:53:34,630
#
# 657
# ["That I know how to freak you the fuck out."]
# 3214.755
# 3216.465
# 00:53:34,755 --> 00:53:36,465
#
# 658
# ["<i>See, if you're talking about", "my fucked-up head</i>"]
# 3217.424
# 3220.469
# 00:53:37,424 --> 00:53:40,469
#
# 659
# ["versus your fucked-up head,"]
# 3221.595
# 3223.972
# 00:53:41,595 --> 00:53:43,972
#
# 660
# ["your fucked-up head is gonna lose."]
# 3226.308
# 3228.477
# 00:53:46,308 --> 00:53:48,477
#
# 661
# ["I figured that would shut you up."]
# 3232.773
# 3234.566
# 00:53:52,773 --> 00:53:54,566
#
# 662
# ["Hey. I can play mind games, too."]
# 3234.983
# 3237.486
# 00:53:54,983 --> 00:53:57,486
#
# 663
# ["(SCREAMS)"]
# 3238.987
# 3240.03
# 00:53:58,987 --> 00:54:00,030
#
# 664
# ["You fucking bitch! You sick fucking bitch!"]
# 3240.155
# 3243.617
# 00:54:00,155 --> 00:54:03,617
#
# 665
# ["We haven't even started."]
# 3243.992
# 3245.494
# 00:54:03,992 --> 00:54:05,494
#
# 666
# ["Got it."]
# 3260.509
# 3261.635
# 00:54:20,509 --> 00:54:21,635
#
# 667
# ["Peach Trees is the manufacturing base"]
# 3267.349
# 3269.268
# 00:54:27,349 --> 00:54:29,268
#
# 668
# ["for all the Slo-Mo in Mega City One."]
# 3269.351
# 3271.895
# 00:54:29,351 --> 00:54:31,895
#
# 669
# ["Ma-Ma's controlling the production"]
# 3271.979
# 3273.147
# 00:54:31,979 --> 00:54:33,147
#
# 670
# ["and distribution across the whole city."]
# 3273.23
# 3275.19
# 00:54:33,230 --> 00:54:35,190
#
# 671
# ["Interesting."]
# 3277.818
# 3279.153
# 00:54:37,818 --> 00:54:39,153
#
# 672
# ["(BUZZER RINGS)"]
# 3285.492
# 3286.702
# 00:54:45,492 --> 00:54:46,702
#
# 673
# ["Peach Trees. Can I help you?"]
# 3290.414
# 3292.04
# 00:54:50,414 --> 00:54:52,040
#
# 674
# ["MALE JUDGE: <i>We're responding to a report of</i>"]
# 3292.416
# 3293.667
# 00:54:52,416 --> 00:54:53,667
#
# 675
# ["<i>Judges under fire from within this block.</i>"]
# 3293.75
# 3295.39
# 00:54:53,750 --> 00:54:55,390
#
# 676
# ["Judges under fire?", "I'm unaware of any such activity."]
# 3295.46
# 3298.297
# 00:54:55,460 --> 00:54:58,297
#
# 677
# ["We're actually undergoing", "a scheduled war defense test."]
# 3298.547
# 3301.008
# 00:54:58,547 --> 00:55:01,008
#
# 678
# ["Not any more, you're not.", "Open the blast door right now."]
# 3301.466
# 3305.387
# 00:55:01,466 --> 00:55:05,387
#
# 679
# ["Yes, sir. The problem is", "we've had a software malfunction"]
# 3305.47
# 3308.891
# 00:55:05,470 --> 00:55:08,891
#
# 680
# ["and I've lost control of the system."]
# 3308.974
# 3310.893
# 00:55:08,974 --> 00:55:10,893
#
# 681
# ["We've had a fire on level 76."]
# 3312.436
# 3314.73
# 00:55:12,436 --> 00:55:14,730
#
# 682
# ["MALE JUDGE: <i>You better get control fast.</i>"]
# 3318.984
# 3320.585
# 00:55:18,984 --> 00:55:20,585
#
# 683
# ["<i>Or I'm slapping you", "with an obstruction of justice charge.</i>"]
# 3320.611
# 3323.488
# 00:55:20,611 --> 00:55:23,488
#
# 684
# ["<i>Five years in the cubes, mandatory.</i>"]
# 3323.572
# 3326.325
# 00:55:23,572 --> 00:55:26,325
#
# 685
# ["Will do, sir. I'm on it right now.", "Thank you."]
# 3326.408
# 3328.744
# 00:55:26,408 --> 00:55:28,744
#
# 686
# ["We have new intel about Ma-Ma,"]
# 3338.045
# 3339.755
# 00:55:38,045 --> 00:55:39,755
#
# 687
# ["and we've managed to get", "a 10-24 to Control."]
# 3339.838
# 3342.216
# 00:55:39,838 --> 00:55:42,216
#
# 688
# ["Parameters are shifting."]
# 3342.299
# 3344.051
# 00:55:42,299 --> 00:55:44,051
#
# 689
# ["What are the options, Anderson?"]
# 3344.134
# 3345.594
# 00:55:44,134 --> 00:55:45,594
#
# 690
# ["Keep moving and attempt to avoid further", "detection, or find a place to defend."]
# 3345.677
# 3349.848
# 00:55:45,677 --> 00:55:49,848
#
# 691
# ["Same as before, except now", "we know backup's inbound."]
# 3349.932
# 3351.972
# 00:55:49,932 --> 00:55:51,972
#
# 692
# ["You're giving us two options.", "Defend or hide."]
# 3352.726
# 3355.27
# 00:55:52,726 --> 00:55:55,270
#
# 693
# ["Yes, sir."]
# 3355.52
# 3356.855
# 00:55:55,520 --> 00:55:56,855
#
# 694
# ["What about we attack.", "Head straight for Ma-Ma."]
# 3357.522
# 3360.108
# 00:55:57,522 --> 00:56:00,108
#
# 695
# ["Is that an option?"]
# 3360.984
# 3362.402
# 00:56:00,984 --> 00:56:02,402
#
# 696
# ["Well, she's guilty. We're Judges."]
# 3363.07
# 3365.614
# 00:56:03,070 --> 00:56:05,614
#
# 697
# ["With backup inbound, I think we should wait"]
# 3366.281
# 3367.866
# 00:56:06,281 --> 00:56:07,866
#
# 698
# ["until the odds have shifted in our favor."]
# 3367.95
# 3369.618
# 00:56:07,950 --> 00:56:09,618
#
# 699
# ["Wrong answer?"]
# 3373.121
# 3374.373
# 00:56:13,121 --> 00:56:14,373
#
# 700
# ["You're the psychic."]
# 3375.415
# 3376.75
# 00:56:15,415 --> 00:56:16,750
#
# 701
# ["Clear."]
# 3388.387
# 3389.388
# 00:56:28,387 --> 00:56:29,388
#
# 702
# ["AMOS: Why didn't you shoot him?"]
# 3399.815
# 3401.483
# 00:56:39,815 --> 00:56:41,483
#
# 703
# ["What do you mean, why didn't I shoot him?", "Why didn't you?"]
# 3401.608
# 3404.945
# 00:56:41,608 --> 00:56:44,945
#
# 704
# ["- Okay, we could do it now.", "- Do it."]
# 3406.405
# 3409.074
# 00:56:46,405 --> 00:56:49,074
#
# 705
# ["Shit! Shit!"]
# 3411.91
# 3413.662
# 00:56:51,910 --> 00:56:53,662
#
# 706
# ["Why did it have to be us who found him?"]
# 3414.579
# 3416.54
# 00:56:54,579 --> 00:56:56,540
#
# 707
# ["All right. Come on. Come on."]
# 3417.457
# 3419.668
# 00:56:57,457 --> 00:56:59,668
#
# 708
# ["DREDD: Info terminal.", "Let's check the schematics."]
# 3424.798
# 3427.259
# 00:57:04,798 --> 00:57:07,259
#
# 709
# ["Freeze!"]
# 3448.488
# 3449.698
# 00:57:28,488 --> 00:57:29,698
#
# 710
# ["Why?"]
# 3454.619
# 3455.662
# 00:57:34,619 --> 00:57:35,662
#
# 711
# ["Why what?"]
# 3458.915
# 3459.958
# 00:57:38,915 --> 00:57:39,958
#
# 712
# ["Well, why should I freeze?"]
# 3462.627
# 3464.004
# 00:57:42,627 --> 00:57:44,004
#
# 713
# ["Because otherwise I'll shoot you."]
# 3467.257
# 3470.093
# 00:57:47,257 --> 00:57:50,093
#
# 714
# ["With the safety on?"]
# 3471.928
# 3473.138
# 00:57:51,928 --> 00:57:53,138
#
# 715
# ["It isn't."]
# 3475.265
# 3476.266
# 00:57:55,265 --> 00:57:56,266
#
# 716
# ["How do you want it, kids?", "Body bags or juve-cubes?"]
# 3482.773
# 3486.735
# 00:58:02,773 --> 00:58:06,735
#
# 717
# ["Makes no difference to me."]
# 3486.818
# 3488.445
# 00:58:06,818 --> 00:58:08,445
#
# 718
# ["AMOS: Fuck!"]
# 3491.907
# 3493.408
# 00:58:11,907 --> 00:58:13,408
#
# 719
# ["DREDD: Stun!"]
# 3496.37
# 3497.454
# 00:58:16,370 --> 00:58:17,454
#
# 720
# ["(GRUNTS)"]
# 3498.747
# 3499.748
# 00:58:18,747 --> 00:58:19,748
#
# 721
# ["(GROANING)"]
# 3506.421
# 3507.422
# 00:58:26,421 --> 00:58:27,422
#
# 722
# ["(KAY PANTING)"]
# 3515.138
# 3516.181
# 00:58:35,138 --> 00:58:36,181
#
# 723
# ["You are so fucked."]
# 3520.519
# 3521.978
# 00:58:40,519 --> 00:58:41,978
#
# 724
# ["CLAN MEMBER 1: Blondie.", "CLAN MEMBER 2: Come on!"]
# 3539.788
# 3541.873
# 00:58:59,788 --> 00:59:01,873
#
# 725
# ["CLAN MEMBER 3: Come on, you bitch."]
# 3541.957
# 3543.792
# 00:59:01,957 --> 00:59:03,792
#
# 726
# ["(ALL YELLING INDISTINCTLY)"]
# 3544.209
# 3545.961
# 00:59:04,209 --> 00:59:05,961
#
# 727
# ["(DOG BARKING)"]
# 3546.044
# 3547.087
# 00:59:06,044 --> 00:59:07,087
#
# 728
# ["CLAN MEMBER 4: Hold her down, man."]
# 3547.17
# 3548.839
# 00:59:07,170 --> 00:59:08,839
#
# 729
# ["(ALL TALKING INDISTINCTLY)"]
# 3549.756
# 3551.216
# 00:59:09,756 --> 00:59:11,216
#
# 730
# ["CLAN TECHIE: Jesus."]
# 3557.097
# 3558.181
# 00:59:17,097 --> 00:59:18,181
#
# 731
# ["Now then, what am I gonna do with you?"]
# 3558.306
# 3559.683
# 00:59:18,306 --> 00:59:19,683
#
# 732
# ["You're going to do nothing."]

# %%
states = Set.new(["empty","number","time","text"])
state = "index"
File.open(subtitle_filename).each do | line |
  line.chomp!
  next if line.empty?
  
  if line.match(/^\d+$/)
    state = "index"
  end

  
  if state == "index"  
    puts state + ':'+line
    state = "time"
    
    next
  end
  if state == "time"
    puts state + ':'+line
    state = "text"
    next
  end
  if state == "text"
    puts state + ':'+line
    if line =~ /<\/i>/
       state = "index"
    end
    next
  end
    
    
  line_number = line
end
# Out:
# index:306
# time:00:23:06,762 --> 00:23:08,764
# text:<i>Copy that. Meat wagon inbound.</i>
# index:307
# time:00:23:09,473 --> 00:23:11,308
# text:All right. Let's get them cuffed.
# index:308
# time:00:23:11,809 --> 00:23:12,851
# text:Move. Up.
# index:309
# time:00:23:15,145 --> 00:23:16,146
# text:(GRUNTS)
# index:310
# time:00:23:20,150 --> 00:23:22,361
# text:Sir, this one's a gang member. He...
# index:311
# time:00:23:29,451 --> 00:23:31,036
# text:Sir, it's him.
# index:312
# time:00:23:31,120 --> 00:23:32,746
# text:Him who?
# index:313
# time:00:23:32,830 --> 00:23:34,631
# text:The man who murdered
# text:the people in the atrium.
# index:314
# time:00:23:36,667 --> 00:23:37,668
# text:You're sure?
# index:315
# time:00:23:40,629 --> 00:23:41,880
# text:99%.
# index:316
# time:00:23:45,009 --> 00:23:47,636
# text:Can't execute a perp on 99%.
# index:317
# time:00:23:52,182 --> 00:23:55,894
# text:Save me a lot of paperwork
# text:if you just confess right now.
# index:318
# time:00:23:59,356 --> 00:24:01,483
# text:We'll take him in.
# index:319
# time:00:24:01,567 --> 00:24:04,445
# text:See how he holds up
# text:after a few hours of interrogation.
# index:320
# time:00:24:10,326 --> 00:24:12,661
# text:(LIGHT ROCK MUSIC PLAYING)
# index:321
# time:00:24:31,180 --> 00:24:32,389
# text:Oh, shit.
# index:322
# time:00:24:34,183 --> 00:24:36,852
# text:Judges. No, no, no...
# index:323
# time:00:24:39,355 --> 00:24:43,067
# text:Uh, Caleb?
# text:There's a problem on level 39.
# index:324
# time:00:24:43,400 --> 00:24:45,880
# text:CALEB: Judges hit the distribution point
# text:and shot the place up.
# index:325
# time:00:24:45,944 --> 00:24:47,446
# text:Took out a few of the boys.
# index:326
# time:00:24:47,529 --> 00:24:49,239
# text:So what? We're overdue a bust.
# index:327
# time:00:24:49,406 --> 00:24:50,658
# text:It's just the judges showing their faces,
# index:328
# time:00:24:50,741 --> 00:24:52,242
# text:reminding the citizens they exist.
# index:329
# time:00:24:52,326 --> 00:24:54,203
# text:No, Ma. They picked up Kay.
# index:330
# time:00:24:54,286 --> 00:24:55,329
# text:Executed?
# index:331
# time:00:24:55,412 --> 00:24:57,706
# text:Interrogation.
# text:They're taking him in right now.
# index:332
# time:00:24:57,790 --> 00:24:58,791
# text:Fuck.
# index:333
# time:00:24:59,333 --> 00:25:00,417
# text:If Kay talks...
# index:334
# time:00:25:00,584 --> 00:25:02,878
# text:If they're taking him in, he'll talk.
# index:335
# time:00:25:05,506 --> 00:25:06,757
# text:What are we gonna do?
# index:336
# time:00:25:33,784 --> 00:25:34,952
# text:(GUN SHOTS)
# index:337
# time:00:25:38,455 --> 00:25:40,290
# text:CALEB: That one's still breathing.
# index:338
# time:00:25:43,460 --> 00:25:44,920
# text:Control room is secure.
# index:339
# time:00:25:52,469 --> 00:25:54,638
# text:Router's in. You're good to go.
# index:340
# time:00:25:57,808 --> 00:25:59,268
# text:OPERATOR:<i> Sector Control.</i>
# index:341
# time:00:26:00,310 --> 00:26:02,396
# text:Sector Control. This is
# text:Peach Tree's control.
# index:342
# time:00:26:02,479 --> 00:26:04,064
# text:I just wanna check you were notified about
# index:343
# time:00:26:04,148 --> 00:26:06,150
# text:the def-con systems test today.
# index:344
# time:00:26:06,233 --> 00:26:07,735
# text:<i>Copy that.</i>
# index:345
# time:00:26:07,818 --> 00:26:09,820
# text:<i>Peach Trees, we don't have
# text:you down for a def-con test.</i>
# index:346
# time:00:26:09,903 --> 00:26:11,572
# text:Yeah, we must be. If you check the...
# index:347
# time:00:26:11,655 --> 00:26:12,990
# text:<i>I've got nothing.</i>
# index:348
# time:00:26:15,993 --> 00:26:17,786
# text:God fucking damn it, Sector!
# index:349
# time:00:26:17,870 --> 00:26:21,206
# text:I put in the notification
# text:myself three fucking times!
# index:350
# time:00:26:21,498 --> 00:26:22,750
# text:We are good to go right now!
# index:351
# time:00:26:22,833 --> 00:26:26,253
# text:I've got my supervisor
# text:breathing down my neck.
# index:352
# time:00:26:26,336 --> 00:26:28,672
# text:<i>Hold fire, Peach Trees.
# text:Let me get on this.</i>
# index:353
# time:00:26:29,339 --> 00:26:31,550
# text:<i>Okay. I put you on the system.</i>
# index:354
# time:00:26:31,633 --> 00:26:33,677
# text:<i>Hall of Justice and all emergency services</i>
# index:355
# time:00:26:33,761 --> 00:26:35,429
# text:<i>are notified to ignore your status.</i>
# index:356
# time:00:26:35,512 --> 00:26:37,681
# text:<i>You can run the test any time you like.</i>
# index:357
# time:00:26:37,848 --> 00:26:39,391
# text:Appreciate that, Sector.
# index:358
# time:00:26:39,641 --> 00:26:41,685
# text:You just saved my ass over here.
# index:359
# time:00:26:42,019 --> 00:26:43,520
# text:<i>You're welcome, Peach Trees.</i>
# index:360
# time:00:26:53,363 --> 00:26:55,991
# text:Sir, he's thinking about
# text:making a move for your gun.
# index:361
# time:00:26:56,700 --> 00:26:57,868
# text:DREDD: Yeah.
# index:362
# time:00:26:59,036 --> 00:27:00,996
# text:He just changed his mind.
# index:363
# time:00:27:01,497 --> 00:27:02,498
# text:Yeah.
# index:364
# time:00:27:07,461 --> 00:27:09,129
# text:CLAN TECHIE: <i>Then enter the pass key</i>
# index:365
# time:00:27:09,213 --> 00:27:10,672
# text:<i>and you should be inside.</i>
# index:366
# time:00:27:13,217 --> 00:27:15,219
# text:AUTOMATED VOICE:
# text:<i>Security protocols accessed.</i>
# index:367
# time:00:27:16,720 --> 00:27:18,514
# text:<i>War protocol accessed.</i>
# index:368
# time:00:27:20,057 --> 00:27:21,850
# text:<i>Blast shield initiated.</i>
# index:369
# time:00:27:27,523 --> 00:27:30,067
# text:Warned you. Get up.
# text:You're headed for the cubes.
# index:370
# time:00:27:30,150 --> 00:27:31,670
# text:AUTOMATED VOICE: <i>Stand clear of doors.</i>
# index:371
# time:00:27:31,735 --> 00:27:33,028
# text:(ALARM BLARING)
# index:372
# time:00:27:35,155 --> 00:27:37,366
# text:<i>All residents remain calm.</i>
# index:373
# time:00:27:39,743 --> 00:27:41,829
# text:<i>All residents remain calm.</i>
# index:374
# time:00:27:43,747 --> 00:27:45,457
# text:<i>All residents remain calm.</i>
# index:375
# time:00:28:04,518 --> 00:28:07,771
# text:(PEOPLE TALKING INDISTINCTLY)
# index:376
# time:00:28:18,198 --> 00:28:19,449
# text:What's going on?
# index:377
# time:00:28:28,375 --> 00:28:30,294
# text:AUTOMATED VOICE: <i>Lockdown complete.</i>
# index:378
# time:00:28:43,098 --> 00:28:44,766
# text:You're patched in.
# index:379
# time:00:29:00,657 --> 00:29:01,909
# text:Peach Trees.
# index:380
# time:00:29:02,993 --> 00:29:04,328
# text:<i>This is Ma-Ma.</i>
# index:381
# time:00:29:05,287 --> 00:29:06,496
# text:(FEEDBACK WHINING)
# index:382
# time:00:29:08,081 --> 00:29:10,584
# text:<i>Somewhere in this block are two judges.</i>
# index:383
# time:00:29:13,170 --> 00:29:14,546
# text:<i>I want them dead.</i>
# index:384
# time:00:29:16,632 --> 00:29:19,176
# text:<i>Until I get what I want,
# text:the block is locked down.</i>
# index:385
# time:00:29:21,678 --> 00:29:25,557
# text:<i>All Clan, every level,
# text:hunt the judges down.</i>
# index:386
# time:00:29:27,267 --> 00:29:29,102
# text:Everyone else, clear the corridors
# index:387
# time:00:29:29,186 --> 00:29:31,772
# text:and stay the fuck out of our way
# text:until the shooting stops.
# index:388
# time:00:29:32,022 --> 00:29:33,357
# text:(ALL CLAMORING)
# index:389
# time:00:29:35,525 --> 00:29:37,235
# text:<i>If I hear of anyone helping the judges,</i>
# index:390
# time:00:29:37,319 --> 00:29:40,530
# text:<i>I will kill them and the next
# text:generation of their family.</i>
# index:391
# time:00:29:47,371 --> 00:29:49,289
# text:<i>As for the judges...</i>
# index:392
# time:00:29:49,373 --> 00:29:51,124
# text:We better move.
# index:393
# time:00:29:51,208 --> 00:29:53,543
# text:<i>...sit tight, or run.</i>
# index:394
# time:00:29:57,339 --> 00:29:59,549
# text:Makes no difference. You're mine.
# index:395
# time:00:30:09,017 --> 00:30:10,227
# text:(CHILD CRYING)
# index:396
# time:00:30:18,860 --> 00:30:20,153
# text:DREDD: Control, we have a situation
# index:397
# time:00:30:20,237 --> 00:30:22,239
# text:developing in Peach Trees.
# text:Do you copy?
# index:398
# time:00:30:22,322 --> 00:30:23,573
# text:(STATIC ON RADIO)
# index:399
# time:00:30:24,241 --> 00:30:25,826
# text:Control, do you copy?
# index:400
# time:00:30:25,909 --> 00:30:27,619
# text:My comms are down too.
# index:401
# time:00:30:27,703 --> 00:30:29,579
# text:Shielding must be blocking
# text:our transmissions.
# index:402
# time:00:30:30,580 --> 00:30:32,332
# text:We'll head for the Med Center.
# index:403
# time:00:30:32,416 --> 00:30:33,583
# text:(MEN SHOUTING)
# index:404
# time:00:30:37,379 --> 00:30:38,755
# text:CLAN MEMBER: They're here!
# index:405
# time:00:30:40,340 --> 00:30:41,633
# text:- Call it.
# text:- Sir?
# index:406
# time:00:30:41,717 --> 00:30:43,552
# text:You're on assessment, Rookie. Call it.
# index:407
# time:00:30:44,928 --> 00:30:46,513
# text:Multiple armed targets.
# text:Obstructed line of sight.
# index:408
# time:00:30:46,596 --> 00:30:48,098
# text:- Gas grenades.
# text:- Respirators.
# index:409
# time:00:30:50,183 --> 00:30:51,685
# text:Advise you hold your breath.
# index:410
# time:00:31:05,615 --> 00:31:07,200
# text:(MEN COUGHING)
# index:411
# time:00:31:21,048 --> 00:31:22,049
# text:(GRUNTING)
# index:412
# time:00:31:33,435 --> 00:31:34,561
# text:(ELEVATOR DINGS)
# index:413
# time:00:31:51,244 --> 00:31:54,414
# text:I want the North and East
# text:corridor totally covered.
# index:414
# time:00:31:54,498 --> 00:31:56,249
# text:Sal's got the West and the South.
# index:415
# time:00:31:56,666 --> 00:31:58,168
# text:And spread out your hardware.
# index:416
# time:00:31:58,752 --> 00:32:01,505
# text:We're gonna hand these judges
# text:back to Ma-Ma on a plate.
# index:417
# time:00:32:04,174 --> 00:32:05,509
# text:(INDISTINCT SHOUTING)
# index:418
# time:00:32:06,176 --> 00:32:08,095
# text:BIG JOE: Stay fucking focused.
# index:419
# time:00:32:08,178 --> 00:32:10,180
# text:CLAN MEMBER 1: Judges got it coming!
# index:420
# time:00:32:13,934 --> 00:32:15,352
# text:(MEN TALKING INDISTINCTLY)
# index:421
# time:00:32:21,942 --> 00:32:23,462
# text:CLAN MEMBER 2: Judge, come and get me.
# index:422
# time:00:32:23,527 --> 00:32:25,654
# text:We're gonna have to go through them.
# index:423
# time:00:32:27,030 --> 00:32:28,615
# text:Stun grenade.
# index:424
# time:00:32:32,661 --> 00:32:34,621
# text:CLAN MEMBER 3: Kill that motherfucker.
# index:425
# time:00:32:34,704 --> 00:32:36,414
# text:Let's give them the good news.
# index:426
# time:00:32:41,878 --> 00:32:44,131
# text:CLAN MEMBER 1: Man up that corridor, man.
# index:427
# time:00:32:44,214 --> 00:32:45,423
# text:CLAN MEMBER 2: Fuck up the judges.
# index:428
# time:00:32:45,507 --> 00:32:46,800
# text:Fuck them.
# index:429
# time:00:32:46,883 --> 00:32:50,554
# text:Citizens of Peach Trees. This is the law.
# index:430
# time:00:32:50,679 --> 00:32:52,556
# text:CLAN MEMBER 3: Who do you think you are
# text:coming up in here?
# index:431
# time:00:32:52,889 --> 00:32:54,349
# text:Disperse immediately,
# index:432
# time:00:32:54,432 --> 00:32:57,269
# text:or we will use lethal
# text:force to clear the area.
# index:433
# time:00:32:57,435 --> 00:32:58,562
# text:CLAN MEMBER 1: Where's that coming from?
# index:434
# time:00:32:58,812 --> 00:33:00,856
# text:Over there. Access corridor.
# index:435
# time:00:33:01,481 --> 00:33:03,567
# text:DREDD: (OVER PA) <i>You have been warned.</i>
# index:436
# time:00:33:04,734 --> 00:33:07,404
# text:You now have 20 seconds to comply.
# index:437
# time:00:33:07,821 --> 00:33:09,781
# text:It's you doing the complying, Judge.
# index:438
# time:00:33:10,240 --> 00:33:12,492
# text:There's 10 of us, only two of you.
# index:439
# time:00:33:13,410 --> 00:33:15,412
# text:Why don't you step out
# text:from behind that doorway
# index:440
# time:00:33:15,537 --> 00:33:16,913
# text:or we're gonna blow the fuck out of you.
# index:441
# time:00:33:17,038 --> 00:33:18,707
# text:Ten seconds to comply.
# index:442
# time:00:33:19,040 --> 00:33:21,251
# text:JAPHET: - Fuck you, Judge.
# text:- You got five.
# index:443
# time:00:33:22,085 --> 00:33:23,545
# text:Thanks for the heads-up.
# index:444
# time:00:33:28,508 --> 00:33:29,593
# text:(GUNFIRE)
# index:445
# time:00:33:32,429 --> 00:33:35,098
# text:(MUFFLED SCREAMING)
# index:446
# time:00:33:39,060 --> 00:33:40,937
# text:(SPUTTERING)
# index:447
# time:00:33:43,440 --> 00:33:44,566
# text:Please.
# index:448
# time:00:33:45,775 --> 00:33:47,527
# text:What are you waiting for, rookie?
# index:449
# time:00:33:47,903 --> 00:33:50,030
# text:His crime is attempted murder of a Judge.
# index:450
# time:00:33:50,113 --> 00:33:51,823
# text:His sentence is death.
# index:451
# time:00:33:54,117 --> 00:33:55,285
# text:Yes, sir.
# index:452
# time:00:34:20,685 --> 00:34:21,895
# text:(INTERCOM BEEPING)
# index:453
# time:00:34:21,978 --> 00:34:23,313
# text:Open up.
# index:454
# time:00:34:24,481 --> 00:34:25,607
# text:<i>Open Up!</i>
# index:455
# time:00:34:27,067 --> 00:34:28,151
# text:<i>Negative, Judge.</i>
# index:456
# time:00:34:28,318 --> 00:34:30,028
# text:<i>You know what's going on out here.</i>
# index:457
# time:00:34:30,237 --> 00:34:31,696
# text:We need a place we can defend.
# index:458
# time:00:34:31,780 --> 00:34:33,448
# text:<i>Then you better find someplace else.</i>
# index:459
# time:00:34:33,531 --> 00:34:35,659
# text:<i>This is a medical facility. Neutral ground.</i>
# index:460
# time:00:34:35,825 --> 00:34:39,329
# text:Neutral? You're not neutral.
# text:You're choosing sides.
# index:461
# time:00:34:39,663 --> 00:34:41,343
# text:<i>Peach Trees has been sealed by blast doors</i>
# index:462
# time:00:34:41,373 --> 00:34:42,958

# %%
require 'streamio-ffmpeg'
# Out:
# false

# %%
movie_filename = "Dredd.mp4"
# Out:
# "Dredd.mp4"

# %%
movie = FFMPEG::Movie.new("Dredd.mp4")
# Out:
# Errno::ENOENT: No such file or directory - the ffprobe binary could not be found in /Library/Frameworks/Python.framework/Versions/2.7/bin:/opt/local/bin:/opt/local/sbin:/Library/Frameworks/Python.framework/Versions/2.7/bin:/Applications/apache-maven-3.2.5/bin://anaconda/bin://anaconda/bin:/Users/josephkeshet/anaconda/bin:/Library/Frameworks/Python.framework/Versions/3.4/bin:/Library/Frameworks/Python.framework/Versions/2.7/bin:/Users/josephkeshet/.rvm/gems/ruby-2.5.1/bin:/Users/josephkeshet/.rvm/gems/ruby-2.5.1@global/bin:/Users/josephkeshet/.rvm/rubies/ruby-2.5.1/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/usr/texbin:/opt/X11/bin:/usr/local/git/bin:/Users/josephkeshet/grails/bin:/Applications/scala-2.11.7/bin:/Users/josephkeshet/.rvm/bin
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/gems/streamio-ffmpeg-3.0.2/lib/streamio-ffmpeg.rb:105:in `which'
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/gems/streamio-ffmpeg-3.0.2/lib/streamio-ffmpeg.rb:59:in `ffprobe_binary'
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/gems/streamio-ffmpeg-3.0.2/lib/ffmpeg/movie.rb:28:in `initialize'
# <main>:in `new'
# <main>:in `<main>'
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/gems/iruby-0.3/lib/iruby/backend.rb:44:in `eval'
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/gems/iruby-0.3/lib/iruby/backend.rb:44:in `eval'
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/gems/iruby-0.3/lib/iruby/backend.rb:12:in `eval'
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/gems/iruby-0.3/lib/iruby/kernel.rb:87:in `execute_request'
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/gems/iruby-0.3/lib/iruby/kernel.rb:47:in `dispatch'
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/gems/iruby-0.3/lib/iruby/kernel.rb:37:in `run'
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/gems/iruby-0.3/lib/iruby/command.rb:70:in `run_kernel'
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/gems/iruby-0.3/lib/iruby/command.rb:34:in `run'
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/gems/iruby-0.3/bin/iruby:5:in `<top (required)>'
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/bin/iruby:23:in `load'
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/bin/iruby:23:in `<main>'
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/bin/ruby_executable_hooks:24:in `eval'
# /Users/josephkeshet/.rvm/gems/ruby-2.5.1/bin/ruby_executable_hooks:24:in `<main>'
